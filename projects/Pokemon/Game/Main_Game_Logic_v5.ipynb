# %% [markdown]
# # Main Game Logic v5
# - Modified: 22 Apr 2025
#     - Uses Gemini 2.5 Flash
#     - Removed storing individual game states in memory as there is now a stitched map
# - Modified: 21 Apr 2025
#     - Prompt modification for better use of image coordinates
# - Modified: 19 Apr 2025
#     - Uses gpt-4.1-mini
#     - Added Coordinate, Action and Prediction Chain of Thought for previous state to check for successful action with current state
#     - Added Coordinates to map image
#         - Changes:
#             - imports: `from Mapstitching.run_imagestitching import run_imagestitching
#                         from Mapstitching.processimages import make_coordinates_global, convertPILToCV2`
#             - inside res: `Current Game Image: <<Images/image_{count}.png>>` -->
# `Current Game Image: <<Images/image_{count}.png>>
# Overall Explored Location Map (ignore player location - not updated): {map_image}`
#
# - Modified: 13 Mar 2025
#     - Uses `parse_yaml` from strictjson (functionality to be added to AgentJo shortly after more testing!)
#     - Added Prediction, Insights, better Context
#     - Added Thoughts streaming

# %%
##### pip installs
# !pip install openai
# !pip install agentjo
# !pip install opencv-python

# %%
from dotenv import load_dotenv
import time
from IPython.display import clear_output

# put your secret keys in your .env
# For instance, if you are using OpenAI, your .env should contain
# export OPENAI_API_KEY = "sk-......."
load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# # Interface with AgentJo

# %%
from strictjson import parse_yaml

# %%
def replace_image_marker_gemini(func):
    """
    A decorator that scans the user prompt for markers in the form <<filename>>.
    For each marker, it attempts to load an image either from a local file (e.g., .png, .jpg, etc.)
    or from an HTTP URL, and replaces the marker with the corresponding image object.
    Local images are loaded via PIL.Image, while HTTP images are fetched using requests
    and wrapped as a types.Part for the Gemini API.
    The resulting list (mixing text and images) is passed to the wrapped function.
    """
    def wrapper(system_prompt: str, user_prompt: str, **kwargs):
        import re
        parts = re.split(r'<<(.*?)>>', user_prompt)
        new_contents = []
        for idx, part in enumerate(parts):
            if idx % 2 == 1:
                image_source = part.strip()
                # Check if the marker is an HTTP(S) URL.
                if image_source.startswith("http://") or image_source.startswith("https://"):
                    try:
                        import requests
                        response = requests.get(image_source)
                        response.raise_for_status()
                        from google.genai import types
                        # Try to get the MIME type from the response headers; default to image/jpeg.
                        mime_type = response.headers.get("Content-Type", "image/jpeg")
                        new_contents.append(types.Part.from_bytes(data=response.content, mime_type=mime_type))
                    except Exception as e:
                        # If fetching the image fails, leave the marker as text.
                        new_contents.append(f"<<{part}>>")
                else:
                    try:
                        from PIL import Image
                        image = Image.open(image_source)
                        new_contents.append(image)
                    except Exception as e:
                        new_contents.append(f"<<{part}>>")
            else:
                if part:
                    new_contents.append(part)
        return func(system_prompt, new_contents, **kwargs)
    return wrapper

@replace_image_marker_gemini
def llm(system_prompt: str, user_prompt, **kwargs):
    """
    Calls the Gemini API. If the user_prompt has been processed into a list (via our decorator),
    it is used directly as the contents; otherwise, the user_prompt is wrapped in a list.
    """
    from google.genai import types
    from google import genai
    import os

    client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

    # Use the user_prompt directly if it's a list, otherwise wrap it.
    contents = user_prompt if isinstance(user_prompt, list) else [user_prompt]

    response = client.models.generate_content(
        model="gemini-2.5-flash-preview-04-17",
        config=types.GenerateContentConfig(system_instruction=system_prompt, 
                                           temperature=0, 
                                          ),
        contents=contents
    )
    
    return response.text

# %%
import requests
import base64
from PIL import Image
from io import BytesIO
from IPython.display import display
import os
import json

BASE_URL = os.environ['BASE_URL']

# Initialize the game
# requests.post(f"{BASE_URL}/init", json={"rom_path": "PokemonRed.gb"})

count = 0

conversation = []
context_schema = {"Long-term Goals": "State your overall goals to win the game, be detailed and specific, list",
"Short-term Goal": "State what you are trying to do now, be detailed and specific. Describe in detail how the game will be when the goal is completed",
"Target Object or Menu Option to Navigate to": "State the target object in grid world or target menu option you are trying to navigate to, NA if nothing",
"Important Information": "Important knowledge about the world that can help with goals",
"Inventory": "Important items in inventory to help with goals",
"Grid Coordinates Visited": "Update with Current Coordinates, list",
"Map Transition Coordinates": "Updated with (map_id, x, y) -> (map_id, x, y) whenever a map_id is changed, list",
"List of NPCs Interacted": "NPCs who you have interacted with in the form of Person_Name (map_id, x, y) - Summary of Dialogue, list",
"List of Insights Gained": "If action is unsuccessful, write down how to make it successful. Be specific and write down full context, list"}
context = ''

# delete past images
from pathlib import Path
folder = Path("Images")
for file in folder.glob("*"):
    if file.is_file():  # Check if it's a file
        file.unlink()

# %% [markdown]
# ### Load image processing scripts for coordinates

# %%
from Mapstitching.run_imagestitching import run_imagestitching
from Mapstitching.processimages import make_coordinates_global, convertPILToCV2

# %%
import json
import requests
import os
from PIL import Image

from io import BytesIO
import base64
from dotenv import load_dotenv
import time
from IPython.display import clear_output

# put your secret keys in your .env
# For instance, if you are using OpenAI, your .env should contain
# export OPENAI_API_KEY = "sk-......."
load_dotenv(override=True)

BASE_URL = os.environ['BASE_URL']
response = requests.get(f"{BASE_URL}/screen?format=base64")
print(response)
screen_data = response.json()["image"]
screen_image = Image.open(BytesIO(base64.b64decode(screen_data)))
game_state = requests.get(f"{BASE_URL}/state").json()
print(game_state['position'])
# display(screen_image)

stitched_image_path, stitched_image, top_left_map = run_imagestitching(screen_image, player_position = (game_state['position']['x'], game_state['position']['y']))  # possible outputs: str: "INVALIDINPUT", "DIALOGUE", numpy.ndarray: image (new map), stitched image (found in existing map)
# Out:
# <Response [200]>
# {'map_id': 0, 'x': 0, 'y': 0}

# %% [markdown]
# # Show the Coord Map

# %%
from Mapstitching.processimages import make_coordinates, make_coordinates_global, convertPILToCV2
import cv2
coord_img = make_coordinates_global(convertPILToCV2(screen_image, color = True), font_scale=0.5, rescaleimg=5, player_position = (game_state['position']['x'], game_state['position']['y']))
converted = Image.fromarray(coord_img)
# converted.save(f"test_{1}.png")
display(converted)
# Out:
# <PIL.Image.Image image mode=RGB size=800x720>

# %% [markdown]
# ### Main loop

# %%
import pprint
while True:
    # Get the current screen
    response = requests.get(f"{BASE_URL}/screen?format=base64")
    screen_data = response.json()["image"]
    screen_image_clean = Image.open(BytesIO(base64.b64decode(screen_data)))
    
    # Save the image in the specified directory with a filename that includes the current count
    screen_image_clean.save(f"Images/image_{count}.png")

    # Get game state
    game_state = requests.get(f"{BASE_URL}/state").json()
    
    # Resize image and add the coordinate text (if not resized with rescaleimg = 5, font will be too low resolution to read)
    coord_img = make_coordinates_global(convertPILToCV2(screen_image_clean, color = True), font_scale=0.5, rescaleimg=5, player_position = (game_state['position']['x'], game_state['position']['y']))
    screen_image = Image.fromarray(coord_img)
    screen_image.save(f"Images/image_{count}_coord.png")

    print(convertPILToCV2(screen_image_clean, color = True).shape)
    # Get map for current image
    stitched_image_path, stitched_image, top_left_map = run_imagestitching(screen_image_clean, player_position = (game_state['position']['x'], game_state['position']['y']))  # possible outputs: str: "INVALIDINPUT", "DIALOGUE", numpy.ndarray: image (new map), stitched image (found in existing map)

    # check valid map (not dialogue, battle, etc.)
    if stitched_image_path in ["INVALIDINPUT", "DIALOGUE"]:
        # print("No map found: Either input is invalid or current image is a dialogue/battle/shop dialouge")
        map_image = "No current map."
    else:
        print("Map found at:", stitched_image_path)
        map_coord_img = make_coordinates_global(stitched_image, font_scale=0.5, rescaleimg=5, top_left_position = top_left_map)
        map_coord_img_pil = Image.fromarray(map_coord_img)
        display(map_coord_img_pil)
        match_map = "Maps"
        save_coordmap_path = f"{stitched_image_path[:stitched_image_path.rindex(match_map)+5]}coords_{stitched_image_path[stitched_image_path.rindex(match_map)+5:]}"
        map_coord_img_pil.save(save_coordmap_path)
        map_image = f"<<{save_coordmap_path}>>"

    display(screen_image_clean)

    # Make a decision based on the state and screen
    # ... AI logic here ...
    for _ in range(3):
        try:
            res = parse_yaml('''Based on the image and game state, make a decision of what to do next.
If previous action did not match up to prediction, try other actions.

Coordinates are given as (map_id, x, y), map_id being the id of the current map, x being the left to right axis, y being the up to down axis
Every map as a unique map_id, if map_id changes, it is treated as changing location. You should explore the new location if it is unexplored.
left in the negative x direction, e.g. (map_id, x, y) to (map_id, x-1, y)
right in the positive x direction, e.g. (map_id, x, y) to (map_id, x+1, y),
up in the negative y direction, e.g. (map_id, x, y) to (map_id, x, y-1)
down in the positive y direction, e.g. (map_id, x, y) to (map_id, x, y+1)
a is typically used for confirming actions, selecting options, and interacting with elements in the game. You can only interact with elements one cell next to you and you must be facing that element.
b is typically used to cancel actions, go back to the previous screen, or exit menus
start is used to open the main menu, allowing players to access options like the Pokémon menu, bag, items, and settings
select is used to register key items, allowing players to quickly access them during gameplay

You can only enter or exit places via doors, ladders, cave holes, staircases.
If inside a house, you can exit via a rectangular floor rug and moving out of the house.
You cannot exit a house via black regions - you need to look for a door or floor rug.
Black map boundaries are not traversable.
You are in red.

If in menu, plan out what button to press and navigate towards that button.

Be detailed in your explanations.
State whether the previous action is successful by seeing whether the predicted state is reflected in the Current State.
Generate Insights if any, to repeat successful actions or to prevent making bad actions.
Output Updated Context as a dictionary to pass on to the next environment interaction.
        ''',
            f'''```
Current State: {count}
Current Game Image: <<Images/image_{count}.png>>
Current Game Image with Coord Overlay: <<Images/image_{count}_coord.png>>
Overall Explored Location Map (ignore player location - not updated): {map_image}
Current RAM State: {game_state}
Current Context: {context}
```
Last 20 Past States: {conversation[-20:]}''',
    output_format = {"Current View": "Enum['World Map', 'Dialogue', 'Menu', '2D Grid', 'Other']",
f"Description for State {count}": f'''Describe Current Game Image in detail for someone without the image to understand. 
Only state what is there and do not hallucinate. Highlight the important information relevant to the Goal or Target Object. 
If dialogue or menu or battle, highlight the options and status and where the cursor is pointing to.
If 2D grid view, state relative positions of all important objects or NPCs with respect to the red player (you) using relative directions of top, bottom, left, right.
If coordinates are over the tiles, state the coordinates of the objects or NPCs.''',
                     f"Coordinates for State {count-1}": "Write exactly previous (map_id, x, y)",
                     f"Action for State {count-1}": "Write exactly previous action, if any",
                     f"Prediction for State {count}": "Write exactly previous prediction, if any",
                     f"Coordinates for State {count}": "State the (map_id, x, y) of Current RAM State",
                     "Is Action Successful": f"Whether the previous prediction matches current state, bool",
                     "Reflection": "Reflect on why the action is successful or not successful. If action is not successful, suggest another alternate action",
                     "Thoughts": "Describe whether past actions are successful and how you plan to achieve your goal",
                     f"Action for State {count}": "Choose an action in line with Thoughts, Enum['up', 'down', 'left', 'right', 'a', 'b', 'start', 'select']",
                     f"Prediction for State {count+1}": "What will happen after the action is done. If it is a movement, state coordinates or menu option that we will expect to be in",
                     "Updated Context": context_schema},
                      llm = llm)

            break

        except Exception as e:
            continue

    # Update the context
    context = res["Updated Context"]
    
    next_move = res[f"Action for State {count}"]
    
    # Add in what happened in previous state in conversation history
    pprint.pprint(res, sort_dicts = False)

    # Show the thoughts
    thoughts = {'Current State': res[f'Description for State {count}'].replace('\n',''), 'Reflection': res['Reflection'], 'Thoughts': res['Thoughts'], 'Action': res[f'Action for State {count}'], f'Prediction for State {count+1}': res[f'Prediction for State {count+1}']}
    requests.post(f"{BASE_URL}/agent/thoughts", json={"thought": json.dumps(thoughts, indent=4)})

    # Show the memory
    requests.post(f"{BASE_URL}/agent/memory", json={"memory": json.dumps({"Short-term Goal": context["Short-term Goal"].replace('\n',''),
                                                                         "Target": context["Target Object or Menu Option to Navigate to"]},
                                                                        indent=4)
                                                   })

    thoughts_internal = {f'Description for State {count}': res[f'Description for State {count}'], f'Thoughts for State {count}': res['Thoughts'], f'Action for State {count}': res[f'Action for State {count}'], f'Prediction for State {count+1}': res[f'Prediction for State {count+1}']}
    conversation.append(json.dumps(thoughts_internal, indent=4))
                      
    # Increment count by 1 for the next image
    count += 1
    
    # Execute an action
    requests.post(f"{BASE_URL}/button", json={"button": next_move, "delay": 4})
    
    # print(game_state)
    # print(game_state['position']['x'])
    # print(game_state['position']['y'])
    
    time.sleep(5)
    clear_output(wait=True)
# Out:
# (144, 160, 3)
# Map found at: /Users/tanchongmin/Desktop/Demo/Pokemon/Maps/Map_2.png
# <PIL.Image.Image image mode=RGB size=1040x1120>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=160x144>
# {'Current View': '2D Grid',
#  'Description for State 61': 'The current view is a 2D grid representing a '
#                              'room.\n'
#                              'The player character (Red) is standing in the '
#                              'room, facing upwards, at coordinates (2, 2).\n'
#                              'To the left and below the player is a bed, '
#                              'occupying the area around coordinates (0,6) to '
#                              '(1,6).\n'
#                              'Below the player is a blue object, possibly a TV '
#                              'or console, at coordinates (3,4).\n'
#                              'Above and slightly to the left of the player is '
#                              'a PC, occupying the area around coordinates '
#                              '(0,0) to (1,0).\n'
#                              'To the right and below the player is a potted '
#                              'plant, occupying the area around coordinates '
#                              '(6,6).\n'
#                              'There is a staircase in the upper right corner '
#                              'of the room, around coordinates (6,0) to (7,1).\n'
#                              'The floor is tiled with a diagonal pattern. The '
#                              'walls are dark grey.\n',
#  'Coordinates for State 60': '(38, 2, 3)',
#  'Action for State 60': 'up',
#  'Prediction for State 61': 'The player character will move one step upwards '
#                             'from (2, 3) to (2, 2). The view will remain the '
#                             '2D grid of the room.',
#  'Coordinates for State 61': '(38, 2, 2)',
#  'Is Action Successful': True,
#  'Reflection': "The previous action of moving 'up' from (2,3) was successful, "
#                'and the player character moved to (2,2) as predicted. This '
#                'confirms that movement is working correctly in this area.',
#  'Thoughts': 'My short-term goal is to exit the bedroom, which is likely via '
#              'the staircase in the upper right corner. I have successfully '
#              'moved upwards to (2,2). To reach the staircase, I need to move '
#              'towards the right side of the room and then upwards. I will '
#              'attempt to move right from my current position (2,2).',
#  'Action for State 61': 'right',
#  'Prediction for State 62': 'The player character will move one step right '
#                             'from (2, 2) to (3, 2). The view will remain the '
#                             '2D grid of the room.',
#  'Updated Context': {'Long-term Goals': ['Become the Pokémon Champion by '
#                                          'defeating the Elite Four.',
#                                          'Complete the Pokédex by catching all '
#                                          'Pokémon.'],
#                      'Short-term Goal': 'Exit the current room (bedroom) to '
#                                         'proceed downstairs and continue the '
#                                         "game's progression.\n"
#                                         'The goal is completed when the player '
#                                         'character is in a new map, likely the '
#                                         'downstairs area of the house.\n',
#                      'Target Object or Menu Option to Navigate to': 'The '
#                                                                     'staircase '
#                                                                     'in the '
#                                                                     'upper '
#                                                                     'right '
#                                                                     'corner of '
#                                                                     'the room.',
#                      'Important Information': ["Pressing 'start' from the "
#                                                'stuck name input screen '
#                                                "(cursor on 'E' at (3,4) with "
#                                                'name "E____") caused the game '
#                                                'to accept the name "E" and '
#                                                'advance the dialogue. This '
#                                                "suggests 'start' can sometimes "
#                                                'force progression or act as a '
#                                                'confirmation in unexpected '
#                                                'situations.',
#                                                "Pressing 'a' advances "
#                                                'dialogue.',
#                                                "Pressing 'a' selects the "
#                                                'highlighted option in a menu.',
#                                                'Movement on the custom name '
#                                                "input grid from 'E' (3,4) was "
#                                                'restricted or broken.',
#                                                "Pressing 'start' can interrupt "
#                                                'dialogue and open the main '
#                                                'menu.',
#                                                'Menu navigation using '
#                                                'directional inputs works '
#                                                'correctly.',
#                                                'Exiting the main menu returns '
#                                                'the player to the game world, '
#                                                'likely after the introduction '
#                                                'sequence.'],
#                      'Inventory': 'NA',
#                      'Grid Coordinates Visited': ['(0, 0, 0)',
#                                                   '(38, 3, 6)',
#                                                   '(-1, 5)',
#                                                   '(3, 4)',
#                                                   '(38, 2, 6)',
#                                                   '(38, 2, 5)',
#                                                   '(38, 2, 4)',
#                                                   '(38, 2, 3)',
#                                                   '(38, 2, 2)'],
#                      'Map Transition Coordinates': [],
#                      'List of NPCs Interacted': [],
#                      'List of Insights Gained': ["Pressing 'a' during the "
#                                                  'introduction sequence might '
#                                                  'skip it and return to the '
#                                                  'main menu. (This insight was '
#                                                  'based on a previous state '
#                                                  "where pressing 'a' from the "
#                                                  'Gengar/Nidorino battle '
#                                                  'returned to the menu. It '
#                                                  'might not apply to '
#                                                  'dialogue.)',
#                                                  "Pressing 'a' successfully "
#                                                  'advances dialogue during '
#                                                  "Professor Oak's "
#                                                  'introduction.',
#                                                  "Pressing 'a' confirms "
#                                                  'prompts during the '
#                                                  'introduction sequence.',
#                                                  "Pressing 'a' selects the "
#                                                  'highlighted option in a '
#                                                  'menu.',
#                                                  'Selecting "NEW NAME" and '
#                                                  "pressing 'a' leads to the "
#                                                  'custom name input screen.',
#                                                  "Moving 'down' from 'A' "
#                                                  '(-0,4) moves the cursor to '
#                                                  "'J' (-1,5).",
#                                                  "Moving 'right' from 'J' "
#                                                  '(-1,5) did not move the '
#                                                  "cursor to 'K' (0,5) in "
#                                                  'previous states.',
#                                                  "Moving 'right' from 'W' "
#                                                  '(3,6) did not move the '
#                                                  'cursor to (4,6). Movement '
#                                                  'might be restricted in '
#                                                  'certain directions or from '
#                                                  'certain positions on the '
#                                                  'name input grid.',
#                                                  "Moving 'up' from 'W' (3,6) "
#                                                  "moves the cursor to 'E' "
#                                                  '(3,4), skipping the row in '
#                                                  'between. The vertical '
#                                                  'movement on the grid is not '
#                                                  'a simple step to the '
#                                                  'adjacent row.',
#                                                  'Selecting a character on the '
#                                                  'name input grid by pressing '
#                                                  "'a' adds the character to "
#                                                  'the name field and the '
#                                                  'cursor remains on the '
#                                                  "selected character's "
#                                                  'position on the grid.',
#                                                  "Movement from 'E' (3,4) "
#                                                  'appears to be restricted or '
#                                                  'broken for left, down, '
#                                                  'right, and up directions.',
#                                                  "Pressing 'b' does not exit "
#                                                  'the custom name input screen '
#                                                  'from the state where the '
#                                                  "cursor is on 'E' at (3,4).",
#                                                  "Pressing 'a' from the stuck "
#                                                  "position on 'E' at (3,4) "
#                                                  'does not add another '
#                                                  'character or change the '
#                                                  'state.',
#                                                  "Pressing 'start' from the "
#                                                  'stuck name input screen '
#                                                  "(cursor on 'E' at (3,4) with "
#                                                  'name "E____") caused the '
#                                                  'game to accept the name "E" '
#                                                  'and advance the dialogue.',
#                                                  "Pressing 'a' from a dialogue "
#                                                  'box successfully advanced to '
#                                                  'the rival naming menu.',
#                                                  'Menu navigation using '
#                                                  'directional inputs works '
#                                                  'correctly on the rival '
#                                                  'naming screen.',
#                                                  'Selecting a rival name from '
#                                                  "the menu by pressing 'a' "
#                                                  'advances the introduction '
#                                                  'dialogue.',
#                                                  "Pressing 'a' does not always "
#                                                  'advance dialogue, as seen in '
#                                                  'the transition from State 46 '
#                                                  'to State 47.',
#                                                  "Pressing 'start' can "
#                                                  'interrupt dialogue and open '
#                                                  'the main menu.',
#                                                  "Pressing 'down' in the main "
#                                                  'menu moves the cursor to the '
#                                                  'next option below.',
#                                                  'Exiting the main menu '
#                                                  'returns the player to the '
#                                                  'game world after the '
#                                                  'introduction sequence.',
#                                                  "Moving 'up' from (3,6) did "
#                                                  'not result in movement to '
#                                                  '(3,5). The path might be '
#                                                  'blocked or the input was not '
#                                                  'registered.',
#                                                  'The previous attempt to move '
#                                                  "'up' from (3,6) failed, "
#                                                  'suggesting the path might be '
#                                                  'blocked or the input was '
#                                                  'missed.',
#                                                  "Movement 'left' from (3,6) "
#                                                  'to (2,6) is successful.',
#                                                  "Movement 'up' from (2,6) to "
#                                                  '(2,5) is successful.',
#                                                  "Movement 'up' from (2,5) to "
#                                                  '(2,4) is successful.',
#                                                  "Movement 'up' from (2,4) to "
#                                                  '(2,3) is successful.',
#                                                  "Movement 'up' from (2,3) to "
#                                                  '(2,2) is successful.']}}
