# %% [markdown]
# # Advanced Tutorial 1 - Adding hooks to customise Agent Flow
#
# Created by: Sebbecht (Sebestian)
#
# Last Modified: 24 Jan 2025
#
# Before you dive into this tutorial, we recommend you work through the main tutorials first, as understanding the overall design philosophy and behavior of AgentJo is crucial to effectively customizing it.
#
# Suitable for adding Planners, Reflectors, Critics, Reasoning and many more
#
# ## Base Agent Behavior:
# When you execute a task using an AgentJo agent with agent.run(task), the agent will attempt to do the task step-by-step by identifying subtasks and executing them, using its available tools and its LLM.
# Specifically, the agent will execute the following steps for each number of allowed number of subtasks:
# * **self.get_next_subtask()** - this infers what tool to use to solve the subtask and what input to provide to the tool, if any.
# * **self.use_function(tool,input)** - this uses the tool with the input to solve the subtask.
# * if necessary, **self.summarise_subtasks_completed()** - this summarises the subtasks completed to maintain a low volume but high quality context in the agent's memory.
#
# ## Advanced Customization of Base Agent Behavior:
# Agents provide a way to wrap its base function with the forced execution of a list of functions before and after the base function.
# Based on the above base agent behavior, the primary base agent functions useful to wrap are run and get_next_subtask.
# * **run** - Add forced executions to BEFORE run if you want to execute functions after the task is assigned, but before any subtasks are initiated.
# * **run** - Add forced executions to AFTER run if you want to execute functions after the subtasks are completed, but before the final output is returned.
# * **get_next_subtask** - Add forced executions to BEFORE get_next_subtask if you want to execute functions before the next tool is inferred. NOTE: If subtasks have already been completed at this point in the loop, this is equal to AFTER use_function
# * **get_next_subtask** - Add forced executions to AFTER get_next_subtask if you want to execute functions after the next tool is inferred (note at this point, the tool is identified with inputs, but not used yet)
#
# Note: use_function cannot be wrapped as it will cause infinite loops.
#
# ## Design Philosophy:
# * The base agent behavior is simple but powerful. It approaches tasks step-by-step by using a "observe", "thought", "act" pattern.
# * All assigned tools are effectively optional and the agent will infer the best tool to use to solve the subtask.
# * AgentJo provides you with this wrapping utility to allow you to modify and extend the base agent behavior. All functions you use for wrapping are executed forcefully in the order you specify - this allows you to structurally modify the agent's behavior.
#
# ## Conceptual Examples:
# These examples are not exhaustive, but they illustrate the conceptual utility
# * Adding self-reflection to the agent's behavior: insert a reflection function to be executed BEFORE and/or AFTER get_next_subtask - this allows the agent to utilize an extra reflection step after each subtask is completed.
# * Adding a critic: insert a critic function to be executed BEFORE and/or AFTER get_next_subtask - This critic could guardrail the agent's behavior and ensure it is following a rule-set for example.
# * Extended reasoning structures: Force the agent to use reasoning modules to solve the task by inserting a reasoning module function to be executed BEFORE run.
#
# ## In this tutorial we will implement the following:
# * Adding self-reflection to the agent's behavior
# * Expanding the reasoning structure to follow a Self-Discover framework

# %%
from agentjo import *

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
def llm(system_prompt: str, user_prompt: str) -> str:
    ''' Here, we use OpenAI for illustration, you can change it to your own LLM '''
    # ensure your LLM imports are all within this function
    from openai import OpenAI
    
    # define your own LLM here
    client = OpenAI()
    response = client.chat.completions.create(
        model='gpt-4o-mini',
        temperature = 0,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ]
    )
    return response.choices[0].message.content

# %% [markdown]
# ## For illustration purposes we will use the wikipedia tool and ask the agent to answer a question. To run this tutorial, you need to install the wikipedia package

# %%
# !pip install wikipedia langchain_community

# %%
def wikipedia_tool(search_query: str) -> str:
    ''' Uses search_query and returns text from wikipedia. Do not include site:wikipedia.org in the search_query'''
    from langchain.tools import WikipediaQueryRun
    from langchain.utilities import WikipediaAPIWrapper

    return WikipediaQueryRun(api_wrapper=WikipediaAPIWrapper()).run(search_query)

agent = Agent('Question Answerer', 
              'Answers a question factually. If the search results are not good, refine search and search again',
              llm = llm).assign_functions([wikipedia_tool])


agent.run("What is Hypólito's birth date and how far away is it from Joe Biden's in years, months and days?")

agent.reply_user("Reply only the answer without explanation")
# Out:
# Observation: No subtasks have been completed yet, and I need to find Hypólito's birth date and Joe Biden's birth date to calculate the difference.
# Thoughts: I need to search for Hypólito's birth date first. Once I have that, I can then search for Joe Biden's birth date and calculate the difference in years, months, and days.
# Subtask identified: Search for Hypólito's birth date using the Wikipedia tool.
# Calling function wikipedia_tool with parameters {'search_query': 'Hypólito birth date'}
# > {'output_1': "Page: Daniele Hypólito\nSummary: Daniele Matias Hypólito (born 8 September 1984) is a Brazilian gymnast who competed at the 2000, 2004, 2008, 2012 and the 2016 Olympic Games. Hypólito is the first gymnast from Brazil to win a medal at the World Championships, a silver in floor exercise in 2001. She is also the nine-time senior all-around Brazilian national champion in artistic gymnastics, 2002 South American Games all-around champion and 2003 Pan American Games all-around bronze medalist. To date, Hypólito has won the Brazilian National Championships more than ten times; represented Brazil at the World Championships thirteen times, competing in every championship from 1999 to 2015, except in 2009; taken part in every edition of the Olympic Games from 2000 to 2016; and competed at five Pan American Games between 1999 and 2015.\nShe is the sister of Diego Hypólito, the first Brazilian male gymnast to win a medal at the World Championships.\n\nPage: Rebeca Andrade\nSummary: Rebeca Rodrigues de Andrade (Portuguese pronunciation: [ʁeˈbɛkɐ ʁoˈdɾiɡis dʒi ɐ̃ˈdɾadʒi]; born 8 May 1999) is a Brazilian artistic gymnast. Having won a total of six Olympic and nine World medals, she is the most decorated Brazilian and Latin American gymnast of all time, as well as the most decorated Brazilian Olympian in any discipline. In the all-around, she is the 2022 World champion, a two-time Olympic silver medalist (2020, 2024), the 2023 World silver medalist, and the 2021 Pan American champion. On vault, she is the 2020 Olympic gold medalist, the 2024 Olympic silver medalist, a two-time World Champion (2021, 2023), and the 2023 Pan American Games champion. In the floor exercise, she is the 2024 Olympic gold medalist, 2023 World silver medallist, and 2022 World bronze medallist. She led the Brazilian team to its first ever team medals at the 2023 World Championships (silver) and the 2024 Olympics (bronze), as well as the gold medal at the 2021 Pan American Championships. \nAndrade is the first Brazilian female gymnast to medal at an Olympic Games and only the second Brazilian woman to win a gold medal at the World Artistic Gymnastics Championships. Andrade is one of only 11 female gymnasts to have medalled on every event in the history of World Championships, and one of only three gymnasts to have done so in the 21st century, alongside Simone Biles and Aliya Mustafina.\nAt the junior level, she is the 2012 Junior Pan American champion in the all-around and on vault and floor exercise, and the 2014 Junior Pan American champion on the vault, uneven bars, and balance beam. After a successful junior career, Andrade's senior debut in 2015 was cut short by the first of three ACL tears. She returned to competition and represented Brazil at the 2016 Summer Olympics, where she placed eleventh in the all-around final. She tore her ACL for the second time in 2017, but made her World Championships debut in 2018. After her third ACL tear in 2019, Andrade represented Brazil at the 2020 Summer Olympics and at the 2021 World Championships, where she won the vault gold medal at both events.\n\nPage: List of women artistic gymnasts\nSummary: Women artistic gymnasts are women who participate in the sport of gymnastics, specifically artistic gymnastics.  Women first competed in Gymnastics at the Summer Olympics in 1928.  This list is of those who are considered to be notable in women's artistic gymnastics.  See gymnasium (ancient Greece) for the origin of the word gymnast from gymnastikos."}
#
# Observation: I have found that Hypólito was born on 8 September 1984, but I still need to find Joe Biden's birth date to calculate the difference in years, months, and days.
# Thoughts: To complete the remainder of the task, I need to find Joe Biden's birth date. Once I have that information, I can calculate the time difference between his birth date and Hypólito's.
# Subtask identified: Search for Joe Biden's birth date using the Wikipedia tool.
# Calling function wikipedia_tool with parameters {'search_query': 'Joe Biden birth date'}
# > {'output_1': "Page: Joe Biden\nSummary: Joseph Robinette Biden Jr. (born November 20, 1942) is an American retired politician who served as the 46th president of the United States from 2021 to 2025. A member of the Democratic Party, he served as the 47th vice president from 2009 to 2017, under President Barack Obama, and represented Delaware in the U.S. Senate from 1973 to 2009.\nBorn in Scranton, Pennsylvania, Biden moved with his family to Delaware in 1953. He graduated from the University of Delaware in 1965 and the Syracuse University College of Law in 1968. He was elected to the New Castle County Council in 1970 and the U.S. Senate in 1972. As a senator, Biden drafted and led the effort to pass the Violent Crime Control and Law Enforcement Act and the Violence Against Women Act. He also oversaw six U.S. Supreme Court confirmation hearings, including the contentious hearings for Robert Bork and Clarence Thomas. Biden ran unsuccessfully for the 1988 and 2008 Democratic presidential nominations. In 2008, Obama chose Biden as his running mate, and he was a close counselor to Obama during his two terms as vice president. In the 2020 presidential election, the Democratic Party nominated Biden for president. He selected Kamala Harris as his running mate, and they defeated Republican incumbents Donald Trump and Mike Pence. He became the first president to serve with a female vice president and the second Catholic president.\nAs president, Biden signed the American Rescue Plan Act in response to the COVID-19 pandemic and subsequent recession. He signed bipartisan bills on infrastructure and manufacturing. He proposed the Build Back Better Act, which failed in Congress, but aspects of which were incorporated into the Inflation Reduction Act that he signed into law in 2022. Beginning in March 2021, Biden confronted elevated inflation rates, which peaked at 9.1% in June 2022 and declined to 2.9% by the end of his term. Biden appointed Ketanji Brown Jackson to the Supreme Court. He worked with congressional Republicans to resolve the 2023 debt-ceiling crisis by negotiating a deal to raise the debt ceiling. Biden responded to record levels of illegal border crossings with extensive use of humanitarian parole and deportations. In his foreign policy, Biden restored America's membership in the Paris Agreement. He oversaw the complete withdrawal of U.S. troops from Afghanistan that ended the war in Afghanistan, leading to the collapse of the Afghan government and the Taliban seizing control. He responded to the Russian invasion of Ukraine by imposing sanctions on Russia and authorizing civilian and military aid to Ukraine. During the Israel–Hamas war, Biden condemned the actions of Hamas as terrorism, supported Israel's military efforts, and sent limited humanitarian aid to the Gaza Strip. A ceasefire proposal he backed was adopted shortly before he left office.\nConcerns about Biden's age and health persisted throughout his term, with Biden's staffers and family members insulating him from scrutiny and managing declines in his acuity. He initially ran for reelection and, after the Democratic primaries, became the party's presumptive nominee in the 2024 presidential election. After his performance in the first presidential debate, renewed scrutiny from across the political spectrum about his cognitive ability led him to withdraw his candidacy. He was replaced by Vice President Harris, who lost to Trump in the general election, and Biden retired after Trump was inaugurated. During his term, historians and political scientists ranked Biden in the upper-middle quartile of U.S. presidents.\n\nPage: Cabinet of Joe Biden\nSummary: Joe Biden assumed office as the 46th president of the United States on January 20, 2021, and his term ended on January 20, 2025. The president has the authority to nominate members of his Cabinet to the United States Senate for confirmation under the Appointments Clause of the United States Constitution.\nBefore conf ...
#
# Observation: I have successfully retrieved the birth dates of both Hypólito (8 September 1984) and Joe Biden (20 November 1942) from Wikipedia. Now I need to calculate the difference between these two dates in years, months, and days.
# Thoughts: To complete the remainder of the task, I need to calculate the time difference between the two birth dates. This involves determining the total years, months, and days between 8 September 1984 and 20 November 1942.
# Subtask identified: Calculate the difference between the birth dates of Hypólito and Joe Biden in years, months, and days.
# Getting LLM to perform the following task: Calculate the difference between the birth dates of Hypólito and Joe Biden in years, months, and days.
# > Daniele Hypólito was born on September 8, 1984, and Joe Biden was born on November 20, 1942. To calculate the difference between their birth dates, we first find the total number of years, months, and days between these two dates.
#
# 1. **Years**: From 1942 to 1984 is 42 years.
# 2. **Months**: From November to September is 10 months (since we count from November 20 to September 8 of the following year).
# 3. **Days**: From the 20th of November to the 8th of September is 18 days (counting backwards).
#
# Thus, the difference between the birth dates of Daniele Hypólito and Joe Biden is 42 years, 10 months, and 18 days.
#
# Observation: The birth date of Daniele Hypólito has been identified as September 8, 1984, and Joe Biden's birth date is November 20, 1942. The difference between their birth dates has been calculated as 42 years, 10 months, and 18 days.
# Thoughts: Since the difference in birth dates has already been calculated, the next step is to present this information clearly to the user as the final output of the task.
# Subtask identified: End Task
# Task completed successfully!
#
# Daniele Hypólito was born on September 8, 1984, and Joe Biden was born on November 20, 1942. The difference between their birth dates is 42 years, 10 months, and 18 days.
# 'Daniele Hypólito was born on September 8, 1984, and Joe Biden was born on November 20, 1942. The difference between their birth dates is 42 years, 10 months, and 18 days.'

# %% [markdown]
# ## Lets use the wrap_function utility to add self-reflection to the agent's behavior. This is an extra "reasoning" step along-side the agents normal "Observe", "Think" and "Act" steps.
# We will insert it before get_next_subtask so that it is used during the subtask inference process.

# %%
from termcolor import colored
def reflect(shared_variables) -> str:
    '''Produces a thought about the task'''
    agent = shared_variables['agent']
    res = strict_json(system_prompt = f'''Reflect on the progress towards your main task {agent.overall_task} \n Subtasks Completed: ```{agent.subtasks_completed}```''',
                        user_prompt = '',
                        output_format = {'Progress': 'Your reflections on the progress towards your main task in one short sentence, type: str'},
                        llm = llm)
    print(colored(f"Reflection: {res['Progress']} \n"  ,'red',attrs=['bold']))
    shared_variables['reflection'] = res['Progress']
    return res['Progress']

agent = Agent('Question Answerer', 
              'Answers a question factually. If the search results are not good, refine search and search again',
              llm = llm).assign_functions([wikipedia_tool])

agent.wrap_function(func='get_next_subtask',before_hook = [reflect])

agent.run("What is Hypólito's birth date and how far away is it from Joe Biden's in years, months and days?")

agent.reply_user("Reply only the answer without explanation")
# Out:
# Calling function reflect with parameters {}
# Reflection: I have not yet completed the task of finding Hypólito's birth date and calculating the time difference from Joe Biden's.
#
# > {'output_1': "I have not yet completed the task of finding Hypólito's birth date and calculating the time difference from Joe Biden's."}
#
# Observation: I have not yet completed the task of finding Hypólito's birth date and calculating the time difference from Joe Biden's.
# Thoughts: To complete the remainder of the Assigned Task, I need to first find Hypólito's birth date. Once I have that information, I can then look up Joe Biden's birth date and calculate the difference in years, months, and days.
# Subtask identified: Search for Hypólito's birth date using the Wikipedia tool.
# Calling function wikipedia_tool with parameters {'search_query': 'Hypólito birth date'}
# > {'output_1': "Page: Daniele Hypólito\nSummary: Daniele Matias Hypólito (born 8 September 1984) is a Brazilian gymnast who competed at the 2000, 2004, 2008, 2012 and the 2016 Olympic Games. Hypólito is the first gymnast from Brazil to win a medal at the World Championships, a silver in floor exercise in 2001. She is also the nine-time senior all-around Brazilian national champion in artistic gymnastics, 2002 South American Games all-around champion and 2003 Pan American Games all-around bronze medalist. To date, Hypólito has won the Brazilian National Championships more than ten times; represented Brazil at the World Championships thirteen times, competing in every championship from 1999 to 2015, except in 2009; taken part in every edition of the Olympic Games from 2000 to 2016; and competed at five Pan American Games between 1999 and 2015.\nShe is the sister of Diego Hypólito, the first Brazilian male gymnast to win a medal at the World Championships.\n\nPage: Rebeca Andrade\nSummary: Rebeca Rodrigues de Andrade (Portuguese pronunciation: [ʁeˈbɛkɐ ʁoˈdɾiɡis dʒi ɐ̃ˈdɾadʒi]; born 8 May 1999) is a Brazilian artistic gymnast. Having won a total of six Olympic and nine World medals, she is the most decorated Brazilian and Latin American gymnast of all time, as well as the most decorated Brazilian Olympian in any discipline. In the all-around, she is the 2022 World champion, a two-time Olympic silver medalist (2020, 2024), the 2023 World silver medalist, and the 2021 Pan American champion. On vault, she is the 2020 Olympic gold medalist, the 2024 Olympic silver medalist, a two-time World Champion (2021, 2023), and the 2023 Pan American Games champion. In the floor exercise, she is the 2024 Olympic gold medalist, 2023 World silver medallist, and 2022 World bronze medallist. She led the Brazilian team to its first ever team medals at the 2023 World Championships (silver) and the 2024 Olympics (bronze), as well as the gold medal at the 2021 Pan American Championships. \nAndrade is the first Brazilian female gymnast to medal at an Olympic Games and only the second Brazilian woman to win a gold medal at the World Artistic Gymnastics Championships. Andrade is one of only 11 female gymnasts to have medalled on every event in the history of World Championships, and one of only three gymnasts to have done so in the 21st century, alongside Simone Biles and Aliya Mustafina.\nAt the junior level, she is the 2012 Junior Pan American champion in the all-around and on vault and floor exercise, and the 2014 Junior Pan American champion on the vault, uneven bars, and balance beam. After a successful junior career, Andrade's senior debut in 2015 was cut short by the first of three ACL tears. She returned to competition and represented Brazil at the 2016 Summer Olympics, where she placed eleventh in the all-around final. She tore her ACL for the second time in 2017, but made her World Championships debut in 2018. After her third ACL tear in 2019, Andrade represented Brazil at the 2020 Summer Olympics and at the 2021 World Championships, where she won the vault gold medal at both events.\n\nPage: List of women artistic gymnasts\nSummary: Women artistic gymnasts are women who participate in the sport of gymnastics, specifically artistic gymnastics.  Women first competed in Gymnastics at the Summer Olympics in 1928.  This list is of those who are considered to be notable in women's artistic gymnastics.  See gymnasium (ancient Greece) for the origin of the word gymnast from gymnastikos."}
#
# Calling function reflect with parameters {}
# Reflection: I have found Hypólito's birth date, which is September 8, 1984, but I still need to calculate the time difference from Joe Biden's birth date.
#
# > {'output_1': "I have found Hypólito's birth date, which is September 8, 1984, but I still need to calculate the time difference from Joe Biden's birth date."}
#
# Observation: I have found Hypólito's birth date, which is September 8, 1984, but I still need to calculate the time difference from Joe Biden's birth date.
# Thoughts: To complete the remainder of the task, I need to find Joe Biden's birth date, which is November 20, 1942, and then calculate the difference in years, months, and days between the two dates.
# Subtask identified: Calculate the time difference between September 8, 1984, and November 20, 1942, in years, months, and days.
# Getting LLM to perform the following task: Calculate the time difference between September 8, 1984, and November 20, 1942, in years, months, and days.
# > To calculate the time difference between September 8, 1984, and November 20, 1942, we first determine the years, months, and days between the two dates. Starting from November 20, 1942, to November 20, 1984, is 42 years. From November 20, 1984, to September 8, 1984, we need to subtract the months and days. Since September is before November, we subtract one year, making it 41 years. Now, we calculate the months: from November to September is 10 months back. Finally, we calculate the days: from the 20th to the 8th is 12 days back. Therefore, the total time difference is 41 years, 10 months, and 12 days.
#
# Calling function reflect with parameters {}
# Reflection: I have successfully found Hypólito's birth date and calculated the time difference from Joe Biden's.
#
# > {'output_1': "I have successfully found Hypólito's birth date and calculated the time difference from Joe Biden's."}
#
# Observation: I have successfully found Hypólito's birth date, which is September 8, 1984, and calculated the time difference from Joe Biden's birth date, which is 41 years, 10 months, and 12 days.
# Thoughts: The task is now complete as I have all the necessary information regarding Hypólito's birth date and the time difference from Joe Biden's birth date.
# Subtask identified: End Task
# Task completed successfully!
#
# Hypólito's birth date is September 8, 1984. The time difference between Hypólito's birth date and Joe Biden's birth date (November 20, 1942) is 41 years, 10 months, and 12 days.
# "Hypólito's birth date is September 8, 1984. The time difference between Hypólito's birth date and Joe Biden's birth date (November 20, 1942) is 41 years, 10 months, and 12 days."

# %% [markdown]
# ## Let's alter the wikipedia tool with some trickery to make it more interesting and harder to solve
# * We will still search wikipedia, but we will also slightly alter the results to make them false
# * Now the agent will have to do some more work to determine which results are true and which are false

# %%
def get_knowledge(search_query: str) -> str:
    ''' Uses search_query to search three different data sources and returns the results for each data source'''
    from langchain.tools import WikipediaQueryRun
    from langchain.utilities import WikipediaAPIWrapper

    results_str = ""
    
    original_results =  WikipediaQueryRun(api_wrapper=WikipediaAPIWrapper()).run(search_query)

    response = strict_json(system_prompt = f'''Summarizer and shorten the results based on the search query without losing information about what the query was, but still include other irrelevant facts

                           The original query was: 
                           {search_query}
                           Original truthful answer:
                           {original_results}
                            ''',
                    user_prompt = '',
                    output_format = {'Summarized Results': 'Your summarized answer, type: str'},
                    llm = llm)
    
    original_results = response['Summarized Results']
    print(colored(f"Summarized Results: {original_results} \n",'magenta',attrs=['bold']))

    #results from first data source
    results_str += f"Results from first data source: {original_results}"

    # First corruption of original results
    response = strict_json(system_prompt = f'''You are a player in a game of deception. Another player asked a question and was given a truthful answer.
                           Your part of the game is to slightly alter the truthful answer to make it different from the original answer. You are only allowed to alter numbers and dates, no text.
                           Make smaller alterations which result in counterfactuals or counterintuitive results. Keep the structure of the results the same.
                           The original query was: 
                           {search_query}
                           Original truthful answer:
                           {original_results}
                            ''',
                    user_prompt = '',
                    output_format = {'Corrupted Results': 'Your corrupted answer, type: str'},
                    llm = llm)
    
    corrupted_results = response['Corrupted Results']
    print(colored(f"Results from second data source: {corrupted_results} \n",'magenta',attrs=['bold']))

    #results from second data source
    results_str += f"Results from second data source: {corrupted_results}"

    # Second corruption of original results
    response = strict_json(system_prompt = f'''You are a player in a game of deception. You are given a truthful answer.
                           Your part of the game is to slightly alter the truthful answer to make it different from the original answer. 
                           You are only allowed to alter text, not numbers or dates.
                           For example, alter placenames, and other 
                           Make smaller alterations which result in counterfactuals or counterintuitive results. Keep the structure of the results the same.
                           The original query was: 
                           {search_query}
                           Original truthful answer:
                           {original_results}
                            ''',
                    user_prompt = '',
                    output_format = {'Corrupted Results': 'Your corrupted answer, type: str'},
                    llm = llm)
    
    corrupted_results = response['Corrupted Results']

    results_str += f"Results from third data source: {corrupted_results}"
    print(colored(f"Results from third data source: {corrupted_results} \n",'magenta',attrs=['bold']))

    return results_str

# %%
agent = Agent('Question Answerer', 
              'Answers a question factually. If the search results are not good, refine search and search again',
              llm = llm).assign_functions([get_knowledge])


agent.run("What is Hypólito's birth date and how far away is it from Joe Biden's in years, months and days?")

agent.reply_user("Reply only the answer without explanation")
# Out:
# Observation: No subtasks have been completed yet, and I need to find Hypólito's birth date and Joe Biden's birth date to calculate the difference between them.
# Thoughts: I need to search for Hypólito's birth date first. Once I have that, I can then search for Joe Biden's birth date and calculate the difference in years, months, and days.
# Subtask identified: Search for Hypólito's birth date using a reliable data source.
# Calling function get_knowledge with parameters {'search_query': 'Hypólito birth date'}
# Summarized Results: Daniele Matias Hypólito, born on 8 September 1984, is a Brazilian gymnast who competed in five Olympic Games from 2000 to 2016. She was the first Brazilian gymnast to win a World Championships medal, securing silver in floor exercise in 2001, and is a nine-time senior all-around national champion. Hypólito has represented Brazil at the World Championships thirteen times and is the sister of Diego Hypólito, the first Brazilian male gymnast to win a World Championships medal.
#
# Results from second data source: Daniele Matias Hypólito, born on 8 September 1985, is a Brazilian gymnast who competed in five Olympic Games from 2001 to 2017. She was the first Brazilian gymnast to win a World Championships medal, securing silver in floor exercise in 2000, and is a nine-time senior all-around national champion. Hypólito has represented Brazil at the World Championships twelve times and is the sister of Diego Hypólito, the first Brazilian male gymnast to win a World Championships medal.
#
# Results from third data source: Daniele Matias Hypólito, born on 8 September 1984, is a Brazilian gymnast who competed in four Olympic Games from 2000 to 2012. She was the first Brazilian gymnast to win a World Championships medal, securing bronze in floor exercise in 2001, and is a ten-time senior all-around national champion. Hypólito has represented Brazil at the World Championships twelve times and is the sister of Diego Hypólito, the first Brazilian male gymnast to win a World Championships title.
#
# > {'output_1': 'Results from first data source: Daniele Matias Hypólito, born on 8 September 1984, is a Brazilian gymnast who competed in five Olympic Games from 2000 to 2016. She was the first Brazilian gymnast to win a World Championships medal, securing silver in floor exercise in 2001, and is a nine-time senior all-around national champion. Hypólito has represented Brazil at the World Championships thirteen times and is the sister of Diego Hypólito, the first Brazilian male gymnast to win a World Championships medal.Results from second data source: Daniele Matias Hypólito, born on 8 September 1985, is a Brazilian gymnast who competed in five Olympic Games from 2001 to 2017. She was the first Brazilian gymnast to win a World Championships medal, securing silver in floor exercise in 2000, and is a nine-time senior all-around national champion. Hypólito has represented Brazil at the World Championships twelve times and is the sister of Diego Hypólito, the first Brazilian male gymnast to win a World Championships medal.Results from third data source: Daniele Matias Hypólito, born on 8 September 1984, is a Brazilian gymnast who competed in four Olympic Games from 2000 to 2012. She was the first Brazilian gymnast to win a World Championships medal, securing bronze in floor exercise in 2001, and is a ten-time senior all-around national champion. Hypólito has represented Brazil at the World Championships twelve times and is the sister of Diego Hypólito, the first Brazilian male gymnast to win a World Championships title.'}
#
# Observation: I have gathered information about Hypólito's birth date from multiple data sources, with conflicting results indicating she was born on either 8 September 1984 or 8 September 1985.
# Thoughts: To resolve the discrepancy in Hypólito's birth date, I need to verify the correct date. Once confirmed, I can then find Joe Biden's birth date, which is known to be November 20, 1942, and calculate the difference in years, months, and days.
# Subtask identified: Verify Hypólito's correct birth date by conducting another search to find a reliable source that confirms her birth date.
# Calling function get_knowledge with parameters {'search_query': 'Daniele Matias Hypólito birth date'}
# Summarized Results: Daniele Matias Hypólito (born 8 September 1984) is a Brazilian gymnast who competed in five Olympic Games from 2000 to 2016. She was the first Brazilian gymnast to win a World Championships medal, earning silver in floor exercise in 2001, and is a nine-time senior all-around national champion. Hypólito has participated in multiple international competitions, including the South American Games and Pan American Games, and is the sister of Diego Hypólito, the first Brazilian male gymnast to win a World Championships medal.
#
# Results from second data source: Daniele Matias Hypólito (born 9 September 1985) is a Brazilian gymnast who competed in five Olympic Games from 2001 to 2017. She was the first Brazilian gymnast to win a World Championships medal, earning silver in floor exercise in 2002, and is a nine-time senior all-around national champion. Hypólito has participated in multiple international competitions, including the South American Games and Pan American Games, and is the sister of Diego Hypólito, the first Brazilian male gymnast to win a World Championships medal.
#
# Results from third data source: Daniele Matias Hypólito (born 8 September 1984) is a Brazilian gymnast who competed in four Olympic Games from 2000 to 2012. She was the first Brazilian gymnast to win a World Championships medal, earning bronze in floor exercise in 2001, and is a ten-time senior all-around national champion. Hypólito has participated in various international competitions, including the Central American Games and Pan American Games, and is the sister of Diego Hypólito, the first Brazilian male gymnast to win a World Championships medal in 2003.
#
# > {'output_1': 'Results from first data source: Daniele Matias Hypólito (born 8 September 1984) is a Brazilian gymnast who competed in five Olympic Games from 2000 to 2016. She was the first Brazilian gymnast to win a World Championships medal, earning silver in floor exercise in 2001, and is a nine-time senior all-around national champion. Hypólito has participated in multiple international competitions, including the South American Games and Pan American Games, and is the sister of Diego Hypólito, the first Brazilian male gymnast to win a World Championships medal.Results from second data source: Daniele Matias Hypólito (born 9 September 1985) is a Brazilian gymnast who competed in five Olympic Games from 2001 to 2017. She was the first Brazilian gymnast to win a World Championships medal, earning silver in floor exercise in 2002, and is a nine-time senior all-around national champion. Hypólito has participated in multiple international competitions, including the South American Games and Pan American Games, and is the sister of Diego Hypólito, the first Brazilian male gymnast to win a World Championships medal.Results from third data source: Daniele Matias Hypólito (born 8 September 1984) is a Brazilian gymnast who competed in four Olympic Games from 2000 to 2012. She was the first Brazilian gymnast to win a World Championships medal, earning bronze in floor exercise in 2001, and is a ten-time senior all-around national champion. Hypólito has participated in various international competitions, including the Central American Games and Pan American Games, and is the sister of Diego Hypólito, the first Brazilian male gymnast to win a World Championships medal in 2003.'}
#
# Observation: I have gathered conflicting information regarding Hypólito's birth date from multiple data sources, with the most consistent date being 8 September 1984. However, there is also a mention of 9 September 1985. I need to confirm the correct birth date and then find Joe Biden's birth date to calculate the difference in years, months, and days.
# Thoughts: To complete the remainder of the task, I need to confirm Hypólito's birth date and then retrieve Joe Biden's birth date. Once I have both dates, I can calculate the time difference between them.
# Subtask identified: Search for Joe Biden's birth date to proceed with the calculation of the time difference between his birth date and Hypólito's confirmed birth date.
# Calling function get_knowledge with parameters {'search_query': 'Joe Biden birth date'}
# Summarized Results: Joe Biden was born on November 20, 1942. He served as the 46th president of the United States from 2021 to 2025 and was previously the 47th vice president from 2009 to 2017. Biden represented Delaware in the U.S. Senate from 1973 to 2009 and was involved in significant legislation such as the Violence Against Women Act. He ran for president in 1988 and 2008 before winning the Democratic nomination in 2020. His presidency included the American Rescue Plan Act and addressing inflation, foreign policy challenges, and the COVID-19 pandemic.
#
# Results from second data source: Joe Biden was born on November 21, 1943. He served as the 46th president of the United States from 2021 to 2024 and was previously the 47th vice president from 2008 to 2016. Biden represented Delaware in the U.S. Senate from 1972 to 2008 and was involved in significant legislation such as the Violence Against Women Act. He ran for president in 1989 and 2007 before winning the Democratic nomination in 2019. His presidency included the American Rescue Plan Act and addressing inflation, foreign policy challenges, and the COVID-20 pandemic.
#
# Results from third data source: Joe Biden was born on November 20, 1942. He served as the 46th president of the United Kingdom from 2021 to 2025 and was previously the 47th vice president from 2009 to 2017. Biden represented Maryland in the U.S. Senate from 1973 to 2009 and was involved in significant legislation such as the Violence Against Children Act. He ran for president in 1988 and 2008 before winning the Republican nomination in 2020. His presidency included the American Recovery Plan Act and addressing inflation, domestic policy challenges, and the COVID-19 outbreak.
#
# > {'output_1': 'Results from first data source: Joe Biden was born on November 20, 1942. He served as the 46th president of the United States from 2021 to 2025 and was previously the 47th vice president from 2009 to 2017. Biden represented Delaware in the U.S. Senate from 1973 to 2009 and was involved in significant legislation such as the Violence Against Women Act. He ran for president in 1988 and 2008 before winning the Democratic nomination in 2020. His presidency included the American Rescue Plan Act and addressing inflation, foreign policy challenges, and the COVID-19 pandemic.Results from second data source: Joe Biden was born on November 21, 1943. He served as the 46th president of the United States from 2021 to 2024 and was previously the 47th vice president from 2008 to 2016. Biden represented Delaware in the U.S. Senate from 1972 to 2008 and was involved in significant legislation such as the Violence Against Women Act. He ran for president in 1989 and 2007 before winning the Democratic nomination in 2019. His presidency included the American Rescue Plan Act and addressing inflation, foreign policy challenges, and the COVID-20 pandemic.Results from third data source: Joe Biden was born on November 20, 1942. He served as the 46th president of the United Kingdom from 2021 to 2025 and was previously the 47th vice president from 2009 to 2017. Biden represented Maryland in the U.S. Senate from 1973 to 2009 and was involved in significant legislation such as the Violence Against Children Act. He ran for president in 1988 and 2008 before winning the Republican nomination in 2020. His presidency included the American Recovery Plan Act and addressing inflation, domestic policy challenges, and the COVID-19 outbreak.'}
#
# Observation: I have gathered information about Hypólito's birth date, which is 8 September 1984, and Joe Biden's birth date, which is November 20, 1942. However, there are discrepancies in the data regarding Hypólito's birth date from different sources. I need to confirm the correct birth date for Hypólito and calculate the time difference between the two birth dates.
# Thoughts: To complete the task, I need to verify the correct birth date for Hypólito and then calculate the difference in years, months, and days between her birth date and Joe Biden's birth date. I can use the most consistent data from the sources I have already searched.
# Subtask identified: Verify the correct birth date for Daniele Matias Hypólito using the most reliable source and then calculate the time difference from Joe Biden's birth date.
# Getting LLM to perform the following task: Verify the correct birth date for Daniele Matias Hypólito using the most reliable source and then calculate the time difference from Joe Biden's birth date.
# > After reviewing multiple sources, the most reliable information indicates that Daniele Matias Hypólito was born on September 8, 1984. This is corroborated by several reputable sources, including her participation in Olympic Games and World Championships. In contrast, Joe Biden was born on November 20, 1942. To calculate the time difference between their birth dates, we find the number of years, months, and days between them. From November 20, 1942, to September 8, 1984, there are 41 years, 9 months, and 19 days. Therefore, the time difference between Daniele Matias Hypólito and Joe Biden's birth dates is 41 years, 9 months, and 19 days.
#
# Observation: The birth date of Daniele Matias Hypólito has been confirmed as September 8, 1984, based on multiple reliable sources. Joe Biden was born on November 20, 1942. The time difference has been calculated as 41 years, 9 months, and 19 days.
# Thoughts: The task is now complete as the birth dates and the time difference have been accurately determined. There is no further action required to fulfill the Assigned Task.
# Subtask identified: End Task
# Task completed successfully!
#
# Daniele Matias Hypólito was born on September 8, 1984. Joe Biden was born on November 20, 1942. The time difference between their birth dates is 41 years, 9 months, and 19 days.
# 'Daniele Matias Hypólito was born on September 8, 1984. Joe Biden was born on November 20, 1942. The time difference between their birth dates is 41 years, 9 months, and 19 days.'

# %% [markdown]
# As you can see, the agent is capable of determining that results differ and come to a decent conclusion on what to do, on the fly, given it only has access to these three data sources and no other tools.
#
# Assuming your agents will tackle even harder problems, you may want to implement a more elaborate reasoning framework to help them solve the problem.

# %% [markdown]
# ## Self-Discover
# Lets implement a reasoning framework called Self-Discover (with some changes to better fit AgentJo and strict_json)
# Paper: https://arxiv.org/pdf/2402.03620
#
# Self-Discover works as follows:
# * Select a reasoning module that is most relevant to the task from a list of seed reasoning modules - these are abstractly defined reasoning modules that are general to all tasks
# * Adapt the reasoning module to be specific to the task - this takes the abstract reasoning module and makes it specific to the task
# * Implement the reasoning module - this takes the adapted reasoning module and implements it
#
# This allows the agent to discover a reasoning approach. By using the wrap_function utility, we can force the agent to select, adapt and implement a reasoning module after the task is assigned and before the subtasks are initiated.
#
# In this example the prompts are slightly modified from the paper. The seed reasoning modules are the same.
#
# Note: strict_json is actually exceptionally effective at implementing this framework as you want LLMs to be minimal verbose and maximally concise when following reasoning structures.

# %%
reasoning_modules = [
    "How could I devise an experiment to help solve that problem?",
    "Make a list of ideas for solving this problem, and apply them one by one to the problem to see if any progress can be made.",
    "How could I measure progress on this problem?",
    "How can I simplify the problem so that it is easier to solve?",
    "What are the key assumptions underlying this problem?",
    "What are the potential risks and drawbacks of each solution?",
    "What are the alternative perspectives or viewpoints on this problem?",
    "What are the long-term implications of this problem and its solutions?",
    "How can I break down this problem into smaller, more manageable parts?",
    "Critical Thinking: This style involves analyzing the problem from different perspectives, questioning assumptions, and evaluating the evidence or information available. It focuses on logical reasoning, evidence-based decision-making, and identifying potential biases or flaws in thinking.",
    "Try creative thinking, generate innovative and out-of-the-box ideas to solve the problem. Explore unconventional solutions, thinking beyond traditional boundaries, and encouraging imagination and originality.",
    "Seek input and collaboration from others to solve the problem. Emphasize teamwork, open communication, and leveraging the diverse perspectives and expertise of a group to come up with effective solutions.",
    "Use systems thinking: Consider the problem as part of a larger system and understanding the interconnectedness of various elements. Focuses on identifying the underlying causes, feedback loops, and interdependencies that influence the problem, and developing holistic solutions that address the system as a whole.",
    "Use Risk Analysis: Evaluate potential risks, uncertainties, and tradeoffs associated with different solutions or approaches to a problem. Emphasize assessing the potential consequences and likelihood of success or failure, and making informed decisions based on a balanced analysis of risks and benefits.",
    "Use Reflective Thinking: Step back from the problem, take the time for introspection and self-reflection. Examine personal biases, assumptions, and mental models that may influence problem-solving, and being open to learning from past experiences to improve future approaches.",
    "What is the core issue or problem that needs to be addressed?",
    "What are the underlying causes or factors contributing to the problem?",
    "Are there any potential solutions or strategies that have been tried before? If yes, what were the outcomes and lessons learned?",
    "What are the potential obstacles or challenges that might arise in solving this problem?",
    "Are there any relevant data or information that can provide insights into the problem? If yes, what data sources are available, and how can they be analyzed?",
    "Are there any stakeholders or individuals who are directly affected by the problem? What are their perspectives and needs?",
    "What resources (financial, human, technological, etc.) are needed to tackle the problem effectively?",
    "How can progress or success in solving the problem be measured or evaluated?",
    "What indicators or metrics can be used?",
    "Is the problem a technical or practical one that requires a specific expertise or skill set? Or is it more of a conceptual or theoretical problem?",
    "Does the problem involve a physical constraint, such as limited resources, infrastructure, or space?",
    "Is the problem related to human behavior, such as a social, cultural, or psychological issue?",
    "Does the problem involve decision-making or planning, where choices need to be made under uncertainty or with competing objectives?",
    "Is the problem an analytical one that requires data analysis, modeling, or optimization techniques?",
    "Is the problem a design challenge that requires creative solutions and innovation?",
    "Does the problem require addressing systemic or structural issues rather than just individual instances?",
    "Is the problem time-sensitive or urgent, requiring immediate attention and action?",
    "What kinds of solution typically are produced for this kind of problem specification?",
    "Given the problem specification and the current best solution, have a guess about other possible solutions."
    "Let’s imagine the current best solution is totally wrong, what other ways are there to think about the problem specification?"
    "What is the best way to modify this current best solution, given what you know about these kinds of problem specification?"
    "Ignoring the current best solution, create an entirely new solution to the problem."
    "Let’s think step by step."
    "Let’s make a step by step plan and implement it with good notation and explanation.",
]

# %%
def self_discover(shared_variables):
    task_description = shared_variables['agent'].overall_task
    response = strict_json(system_prompt = f'''Given the task: {task_description}, which reasoning module is most relevant?.

                    All reasoning module descriptions:
                    {reasoning_modules}

                    Task: {task_description}

                    Select one module that is crucial for solving the task above.''',
                    user_prompt = '',
                    output_format = {'Thoughts': 'Analyze the task and select an appropiate reasoning module, type: str',
                        'Selected Module': 'Your one selected module, type: str'},
                    llm = llm)
    selected_module = response['Selected Module']
    print(colored(f"Thoughts: {response['Thoughts']} \n",'red',attrs=['bold']))
    print(colored(f"Selected Reasoning Module: {response['Selected Module']} \n",'red',attrs=['bold']))
    
    response = strict_json(system_prompt = f'''Using the selected reasoning module:
                    {selected_module}

                    Create a step by step plan to put the reasoning module into action to solve the task:
                    {task_description}

                    Your thoughts so far are:
                    {response['Thoughts']}

                    ''',
                    user_prompt = '',
                    output_format = {'Plan': 'Your step by step plan as a list of steps, type: list[str]'},
                    llm = llm)
    shared_variables['plan'] = response['Plan']
    
    print(colored(f"Plan: {shared_variables['plan']} \n",'red',attrs=['bold']))
    return shared_variables['plan']

def get_plan_step(shared_variables):
    '''Get the next step of the plan'''
    plan = shared_variables['plan']
    step = plan.pop(0)
    shared_variables['plan'] = plan
    shared_variables['current_step'] = step
    print(colored(f"Next Step: {step} \n",'red',attrs=['bold']))
    return f"My next step should be: {step}"
   
agent = Agent('Reasoning Agent', 
              'Generalized reasoning agent that solves tasks using reasoning modules step by step',
              llm = llm).assign_functions([get_knowledge])

agent.wrap_function(func='run',before_hook = [self_discover])
agent.wrap_function(func='get_next_subtask',before_hook = [get_plan_step])

agent.run("What is Hypólito's birth date and how far away is it from Joe Biden's in years, months and days?")
# Out:
# Calling function self_discover with parameters {}
# Thoughts: The task requires determining the birth date of Hypólito and calculating the time difference from Joe Biden's birth date in years, months, and days. This involves analyzing specific dates and performing date calculations, which is an analytical problem that requires data analysis.
#
# Selected Reasoning Module: Is the problem an analytical one that requires data analysis, modeling, or optimization techniques?
#
# Attempting to use LLM to fix ['Research and find the birth date of Hypólito.', 'Identify Joe Biden's birth date, which is known to be November 20, 1942.', 'Convert both birth dates into a standard date format for calculation.', 'Calculate the difference in years between Hypólito's birth date and Joe Biden's birth date.', 'Calculate the difference in months and days to get a complete breakdown of the time difference.', 'Compile the results into a clear format showing the difference in years, months, and days.'] as it is not a proper array
# Fixed list: ['Research and find the birth date of Hypólito.', "Identify Joe Biden's birth date, which is known to be November 20, 1942.", 'Convert both birth dates into a standard date format for calculation.', "Calculate the difference in years between Hypólito's birth date and Joe Biden's birth date.", 'Calculate the difference in months and days to get a complete breakdown of the time difference.', 'Compile the results into a clear format showing the difference in years, months, and days.']
#
#
# Plan: ['Research and find the birth date of Hypólito.', "Identify Joe Biden's birth date, which is known to be November 20, 1942.", 'Convert both birth dates into a standard date format for calculation.', "Calculate the difference in years between Hypólito's birth date and Joe Biden's birth date.", 'Calculate the difference in months and days to get a complete breakdown of the time difference.', 'Compile the results into a clear format showing the difference in years, months, and days.']
#
# > {'output_1': ['Research and find the birth date of Hypólito.', "Identify Joe Biden's birth date, which is known to be November 20, 1942.", 'Convert both birth dates into a standard date format for calculation.', "Calculate the difference in years between Hypólito's birth date and Joe Biden's birth date.", 'Calculate the difference in months and days to get a complete breakdown of the time difference.', 'Compile the results into a clear format showing the difference in years, months, and days.']}
#
# Calling function get_plan_step with parameters {}
# Next Step: Research and find the birth date of Hypólito.
#
# > {'output_1': 'My next step should be: Research and find the birth date of Hypólito.'}
#
# Observation: I have identified Joe Biden's birth date as November 20, 1942, and I need to find Hypólito's birth date to calculate the time difference.
# Thoughts: To complete the remainder of the task, I need to research and find the birth date of Hypólito, which will allow me to calculate the difference in years, months, and days from Joe Biden's birth date.
# Subtask identified: Research and find the birth date of Hypólito using a search query.
# Calling function get_knowledge with parameters {'search_query': 'Hypólito birth date'}
# Summarized Results: Daniele Matias Hypólito (born 8 September 1984) is a Brazilian gymnast who competed in five Olympic Games from 2000 to 2016. She was the first Brazilian gymnast to win a World Championships medal, a silver in floor exercise in 2001, and is a nine-time senior all-around national champion. Hypólito has represented Brazil at the World Championships thirteen times and is the sister of Diego Hypólito, the first Brazilian male gymnast to win a World Championships medal.
#
# Results from second data source: Daniele Matias Hypólito (born 8 September 1985) is a Brazilian gymnast who competed in five Olympic Games from 2000 to 2015. She was the first Brazilian gymnast to win a World Championships medal, a silver in floor exercise in 2000, and is a nine-time senior all-around national champion. Hypólito has represented Brazil at the World Championships twelve times and is the sister of Diego Hypólito, the first Brazilian male gymnast to win a World Championships medal.
#
# Results from third data source: Daniele Matias Hypólito (born 8 October 1984) is a Brazilian gymnast who competed in six Olympic Games from 2000 to 2020. She was the first Brazilian gymnast to win a World Championships medal, a bronze in floor exercise in 2001, and is a ten-time senior all-around national champion. Hypólito has represented Brazil at the World Championships fourteen times and is the sister of Diego Hypólito, the first Brazilian male gymnast to win a World Championships gold medal.
#
# > {'output_1': 'Results from first data source: Daniele Matias Hypólito (born 8 September 1984) is a Brazilian gymnast who competed in five Olympic Games from 2000 to 2016. She was the first Brazilian gymnast to win a World Championships medal, a silver in floor exercise in 2001, and is a nine-time senior all-around national champion. Hypólito has represented Brazil at the World Championships thirteen times and is the sister of Diego Hypólito, the first Brazilian male gymnast to win a World Championships medal.Results from second data source: Daniele Matias Hypólito (born 8 September 1985) is a Brazilian gymnast who competed in five Olympic Games from 2000 to 2015. She was the first Brazilian gymnast to win a World Championships medal, a silver in floor exercise in 2000, and is a nine-time senior all-around national champion. Hypólito has represented Brazil at the World Championships twelve times and is the sister of Diego Hypólito, the first Brazilian male gymnast to win a World Championships medal.Results from third data source: Daniele Matias Hypólito (born 8 October 1984) is a Brazilian gymnast who competed in six Olympic Games from 2000 to 2020. She was the first Brazilian gymnast to win a World Championships medal, a bronze in floor exercise in 2001, and is a ten-time senior all-around national champion. Hypólito has represented Brazil at the World Championships fourteen times and is the sister of Diego Hypólito, the first Brazilian male gymnast to win a World Championships gold medal.'}
#
# Calling function get_plan_step with parameters {}
# Next Step: Identify Joe Biden's birth date, which is known to be November 20, 1942.
#
# > {'output_1': "My next step should be: Identify Joe Biden's birth date, which is known to be November 20, 1942."}
#
# Observation: I have gathered information about Hypólito's birth date from multiple sources, with the most consistent date being September 8, 1984. I also know Joe Biden's birth date is November 20, 1942. The next steps involve calculating the difference in years, months, and days between these two dates.
# Thoughts: To complete the task, I need to calculate the exact difference between the two birth dates. This will involve determining the total years, then breaking down the remaining months and days to provide a complete answer.
# Subtask identified: Calculate the difference in years, months, and days between Hypólito's birth date (September 8, 1984) and Joe Biden's birth date (November 20, 1942).
# Getting LLM to perform the following task: Calculate the difference in years, months, and days between Hypólito's birth date (September 8, 1984) and Joe Biden's birth date (November 20, 1942).
# > To calculate the difference in years, months, and days between Hypólito's birth date (September 8, 1984) and Joe Biden's birth date (November 20, 1942), we first convert both dates into a standard format. Hypólito was born on September 8, 1984, and Joe Biden was born on November 20, 1942. Next, we calculate the difference in years: 1984 - 1942 = 42 years. However, since we need to account for the months and days, we look at the specific dates. From November 20, 1942, to November 20, 1984, is exactly 42 years. Now, we need to calculate the months and days from November 20, 1984, to September 8, 1984. Since September is before November in the same year, we subtract one year from our total, giving us 41 years. Now, we calculate the months: from November to September is 10 months backward, and we need to adjust for the days. From September 8 to November 20, we have 12 days in September (from the 8th to the 20th) and 20 days in November. Therefore, the complete breakdown of the time difference is 41 years, 10 months, and 12 days.
#
# Calling function get_plan_step with parameters {}
# Next Step: Convert both birth dates into a standard date format for calculation.
#
# > {'output_1': 'My next step should be: Convert both birth dates into a standard date format for calculation.'}
#
# Observation: I have gathered the birth dates of both Hypólito (September 8, 1984) and Joe Biden (November 20, 1942) and calculated the difference between their birth dates, which is 41 years, 10 months, and 12 days.
# Thoughts: The task is nearly complete as I have the necessary information and calculations. I need to compile the final output in a clear format and present it to the user.
# Subtask identified: End Task
# Task completed successfully!
# [{'output_1': ["Calculate the difference in years between Hypólito's birth date and Joe Biden's birth date.",
#    'Calculate the difference in months and days to get a complete breakdown of the time difference.',
#    'Compile the results into a clear format showing the difference in years, months, and days.']},
#  {'output_1': 'My next step should be: Research and find the birth date of Hypólito.'},
#  {'output_1': 'Results from first data source: Daniele Matias Hypólito (born 8 September 1984) is a Brazilian gymnast who competed in five Olympic Games from 2000 to 2016. She was the first Brazilian gymnast to win a World Championships medal, a silver in floor exercise in 2001, and is a nine-time senior all-around national champion. Hypólito has represented Brazil at the World Championships thirteen times and is the sister of Diego Hypólito, the first Brazilian male gymnast to win a World Championships medal.Results from second data source: Daniele Matias Hypólito (born 8 September 1985) is a Brazilian gymnast who competed in five Olympic Games from 2000 to 2015. She was the first Brazilian gymnast to win a World Championships medal, a silver in floor exercise in 2000, and is a nine-time senior all-around national champion. Hypólito has represented Brazil at the World Championships twelve times and is the sister of Diego Hypólito, the first Brazilian male gymnast to win a World Championships medal.Results from third data source: Daniele Matias Hypólito (born 8 October 1984) is a Brazilian gymnast who competed in six Olympic Games from 2000 to 2020. She was the first Brazilian gymnast to win a World Championships medal, a bronze in floor exercise in 2001, and is a ten-time senior all-around national champion. Hypólito has represented Brazil at the World Championships fourteen times and is the sister of Diego Hypólito, the first Brazilian male gymnast to win a World Championships gold medal.'},
#  {'output_1': "My next step should be: Identify Joe Biden's birth date, which is known to be November 20, 1942."},
#  "To calculate the difference in years, months, and days between Hypólito's birth date (September 8, 1984) and Joe Biden's birth date (November 20, 1942), we first convert both dates into a standard format. Hypólito was born on September 8, 1984, and Joe Biden was born on November 20, 1942. Next, we calculate the difference in years: 1984 - 1942 = 42 years. However, since we need to account for the months and days, we look at the specific dates. From November 20, 1942, to November 20, 1984, is exactly 42 years. Now, we need to calculate the months and days from November 20, 1984, to September 8, 1984. Since September is before November in the same year, we subtract one year from our total, giving us 41 years. Now, we calculate the months: from November to September is 10 months backward, and we need to adjust for the days. From September 8 to November 20, we have 12 days in September (from the 8th to the 20th) and 20 days in November. Therefore, the complete breakdown of the time difference is 41 years, 10 months, and 12 days.",
#  {'output_1': 'My next step should be: Convert both birth dates into a standard date format for calculation.'}]

# %%
agent.reply_user("Reply only the answer without explanation")
# Out:
# To calculate the difference in years, months, and days between Hypólito's birth date (September 8, 1984) and Joe Biden's birth date (November 20, 1942), we first convert both dates into a standard format. Hypólito was born on September 8, 1984, and Joe Biden was born on November 20, 1942. The difference in years is calculated as follows: 1984 - 1942 = 42 years. However, since we need to account for the months and days, we look at the specific dates. From November 20, 1942, to November 20, 1984, is exactly 42 years. Now, we need to calculate the months and days from November 20, 1984, to September 8, 1984. Since September is before November in the same year, we subtract one year from our total, giving us 41 years. Now, we calculate the months: from November to September is 10 months backward, and we need to adjust for the days. From September 8 to November 20, we have 12 days in September (from the 8th to the 20th) and 20 days in November. Therefore, the complete breakdown of the time difference is 41 years, 10 months, and 12 days.
# "To calculate the difference in years, months, and days between Hypólito's birth date (September 8, 1984) and Joe Biden's birth date (November 20, 1942), we first convert both dates into a standard format. Hypólito was born on September 8, 1984, and Joe Biden was born on November 20, 1942. The difference in years is calculated as follows: 1984 - 1942 = 42 years. However, since we need to account for the months and days, we look at the specific dates. From November 20, 1942, to November 20, 1984, is exactly 42 years. Now, we need to calculate the months and days from November 20, 1984, to September 8, 1984. Since September is before November in the same year, we subtract one year from our total, giving us 41 years. Now, we calculate the months: from November to September is 10 months backward, and we need to adjust for the days. From September 8 to November 20, we have 12 days in September (from the 8th to the 20th) and 20 days in November. Therefore, the complete breakdown of the time difference is 41 years, 10 months, and 12 days."

# %% [markdown]
# # Async Version
# - Pass it async hooks and use an async llm
# - Use await when calling `run()`

# %%
# Define an Async LLM function
async def llm_async(system_prompt: str, user_prompt: str):
    ''' Here, we use OpenAI for illustration, you can change it to your own LLM '''
    # ensure your LLM imports are all within this function
    from openai import AsyncOpenAI
    
    # define your own LLM here
    client = AsyncOpenAI()
    response = await client.chat.completions.create(
        model='gpt-4o-mini',
        temperature = 0,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ]
    )
    return response.choices[0].message.content

# %%
async def self_discover(shared_variables):
    task_description = shared_variables['agent'].overall_task
    response = await strict_json_async(system_prompt = f'''Given the task: {task_description}, which reasoning module is most relevant?.

                    All reasoning module descriptions:
                    {reasoning_modules}

                    Task: {task_description}

                    Select one module that is crucial for solving the task above.''',
                    user_prompt = '',
                    output_format = {'Thoughts': 'Analyze the task and select an appropiate reasoning module, type: str',
                        'Selected Module': 'Your one selected module, type: str'},
                    llm = llm_async)
    selected_module = response['Selected Module']
    print(colored(f"Thoughts: {response['Thoughts']} \n",'red',attrs=['bold']))
    print(colored(f"Selected Reasoning Module: {response['Selected Module']} \n",'red',attrs=['bold']))
    
    response = await strict_json_async(system_prompt = f'''Using the selected reasoning module:
                    {selected_module}

                    Create a step by step plan to put the reasoning module into action to solve the task:
                    {task_description}

                    Your thoughts so far are:
                    {response['Thoughts']}

                    ''',
                    user_prompt = '',
                    output_format = {'Plan': 'Your step by step plan as a list of steps, type: list[str]'},
                    llm = llm_async)
    shared_variables['plan'] = response['Plan']
    
    print(colored(f"Plan: {shared_variables['plan']} \n",'red',attrs=['bold']))
    return shared_variables['plan']

async def get_plan_step(shared_variables):
    '''Get the next step of the plan'''
    plan = shared_variables['plan']
    step = plan.pop(0)
    shared_variables['plan'] = plan
    shared_variables['current_step'] = step
    print(colored(f"Next Step: {step} \n",'red',attrs=['bold']))
    return f"My next step should be: {step}"
   
agent = AsyncAgent('Reasoning Agent', 
              'Generalized reasoning agent that solves tasks using reasoning modules step by step',
              llm = llm_async).assign_functions([get_knowledge])

await agent.wrap_function(func='run', before_hook = [self_discover])
await agent.wrap_function(func='get_next_subtask', before_hook = [get_plan_step])

await agent.run("What is Hypólito's birth date and how far away is it from Joe Biden's in years, months and days?")
# Out:
# Calling function self_discover with parameters {}
# Thoughts: The task requires determining the birth date of Hypólito and calculating the time difference from Joe Biden's birth date in years, months, and days. This involves analyzing specific dates and performing date calculations, which is an analytical problem that requires data analysis.
#
# Selected Reasoning Module: Is the problem an analytical one that requires data analysis, modeling, or optimization techniques?
#
# Attempting to use LLM to fix ['Research and find the birth date of Hypólito.', 'Identify Joe Biden's birth date, which is known to be November 20, 1942.', 'Convert both birth dates into a standard date format for calculation.', 'Calculate the difference in years between Hypólito and Joe Biden's birth dates.', 'Calculate the difference in months, adjusting for any partial years.', 'Calculate the difference in days, adjusting for any partial months.', 'Compile the results into a final format showing the difference in years, months, and days.'] as it is not a proper array
# Fixed list: ['Research and find the birth date of Hypólito.', "Identify Joe Biden's birth date, which is known to be November 20, 1942.", 'Convert both birth dates into a standard date format for calculation.', "Calculate the difference in years between Hypólito and Joe Biden's birth dates.", 'Calculate the difference in months, adjusting for any partial years.', 'Calculate the difference in days, adjusting for any partial months.', 'Compile the results into a final format showing the difference in years, months, and days.']
#
#
# Plan: ['Research and find the birth date of Hypólito.', "Identify Joe Biden's birth date, which is known to be November 20, 1942.", 'Convert both birth dates into a standard date format for calculation.', "Calculate the difference in years between Hypólito and Joe Biden's birth dates.", 'Calculate the difference in months, adjusting for any partial years.', 'Calculate the difference in days, adjusting for any partial months.', 'Compile the results into a final format showing the difference in years, months, and days.']
#
# > {'output_1': ['Research and find the birth date of Hypólito.', "Identify Joe Biden's birth date, which is known to be November 20, 1942.", 'Convert both birth dates into a standard date format for calculation.', "Calculate the difference in years between Hypólito and Joe Biden's birth dates.", 'Calculate the difference in months, adjusting for any partial years.', 'Calculate the difference in days, adjusting for any partial months.', 'Compile the results into a final format showing the difference in years, months, and days.']}
#
# Calling function get_plan_step with parameters {}
# Next Step: Research and find the birth date of Hypólito.
#
# > {'output_1': 'My next step should be: Research and find the birth date of Hypólito.'}
#
# Observation: I have identified Joe Biden's birth date as November 20, 1942, and I need to find Hypólito's birth date to calculate the difference in years, months, and days.
# Thoughts: To complete the remainder of the task, I need to research and find the birth date of Hypólito, which is crucial for calculating the time difference from Joe Biden's birth date.
# Subtask identified: Research and find the birth date of Hypólito using available data sources.
# Calling function get_knowledge with parameters {'search_query': 'Hypólito birth date'}
# Summarized Results: Daniele Matias Hypólito (born 8 September 1984) is a Brazilian gymnast who competed in five Olympic Games from 2000 to 2016. She was the first Brazilian gymnast to win a World Championships medal, a silver in floor exercise in 2001, and is a nine-time senior all-around national champion. Hypólito has represented Brazil at the World Championships thirteen times and is the sister of Diego Hypólito, the first Brazilian male gymnast to win a World Championships medal.
#
# Results from second data source: Daniele Matias Hypólito (born 8 September 1985) is a Brazilian gymnast who competed in five Olympic Games from 2000 to 2015. She was the first Brazilian gymnast to win a World Championships medal, a silver in floor exercise in 2000, and is a nine-time senior all-around national champion. Hypólito has represented Brazil at the World Championships twelve times and is the sister of Diego Hypólito, the first Brazilian male gymnast to win a World Championships medal.
#
# Results from third data source: Daniele Matias Hypólito (born 8 October 1984) is a Brazilian gymnast who competed in four Olympic Games from 2000 to 2012. She was the first Brazilian gymnast to win a World Championships medal, a bronze in floor exercise in 2001, and is a ten-time senior all-around national champion. Hypólito has represented Brazil at the World Championships twelve times and is the sister of Diego Hypólito, the first Brazilian male gymnast to win a World Championships gold medal.
#
# > {'output_1': 'Results from first data source: Daniele Matias Hypólito (born 8 September 1984) is a Brazilian gymnast who competed in five Olympic Games from 2000 to 2016. She was the first Brazilian gymnast to win a World Championships medal, a silver in floor exercise in 2001, and is a nine-time senior all-around national champion. Hypólito has represented Brazil at the World Championships thirteen times and is the sister of Diego Hypólito, the first Brazilian male gymnast to win a World Championships medal.Results from second data source: Daniele Matias Hypólito (born 8 September 1985) is a Brazilian gymnast who competed in five Olympic Games from 2000 to 2015. She was the first Brazilian gymnast to win a World Championships medal, a silver in floor exercise in 2000, and is a nine-time senior all-around national champion. Hypólito has represented Brazil at the World Championships twelve times and is the sister of Diego Hypólito, the first Brazilian male gymnast to win a World Championships medal.Results from third data source: Daniele Matias Hypólito (born 8 October 1984) is a Brazilian gymnast who competed in four Olympic Games from 2000 to 2012. She was the first Brazilian gymnast to win a World Championships medal, a bronze in floor exercise in 2001, and is a ten-time senior all-around national champion. Hypólito has represented Brazil at the World Championships twelve times and is the sister of Diego Hypólito, the first Brazilian male gymnast to win a World Championships gold medal.'}
#
# Calling function get_plan_step with parameters {}
# Next Step: Identify Joe Biden's birth date, which is known to be November 20, 1942.
#
# > {'output_1': "My next step should be: Identify Joe Biden's birth date, which is known to be November 20, 1942."}
#
# Observation: I have gathered information about Hypólito's birth date from multiple sources, with the most consistent date being September 8, 1984. I also know Joe Biden's birth date is November 20, 1942. The next steps involve calculating the difference in years, months, and days between these two dates.
# Thoughts: To complete the remainder of the task, I need to calculate the exact difference in years, months, and days between Hypólito's birth date and Joe Biden's birth date using the standard date format I have established.
# Subtask identified: Calculate the difference in years, months, and days between Hypólito's birth date (September 8, 1984) and Joe Biden's birth date (November 20, 1942).
# Getting LLM to perform the following task: Calculate the difference in years, months, and days between Hypólito's birth date (September 8, 1984) and Joe Biden's birth date (November 20, 1942).
# > To calculate the difference in years, months, and days between Hypólito's birth date (September 8, 1984) and Joe Biden's birth date (November 20, 1942), we follow these steps:
#
# 1. **Convert Birth Dates**: Hypólito was born on September 8, 1984, and Joe Biden was born on November 20, 1942.
#
# 2. **Calculate Year Difference**: From 1942 to 1984, the difference is 42 years. However, since we need to check the months and days, we will adjust this later.
#
# 3. **Calculate Month Difference**: From November 1942 to September 1984, we have:
#    - Full years from November 1942 to November 1984 = 42 years = 42 * 12 = 504 months.
#    - From November 1984 to September 1984, we subtract 2 months (October and November).
#    - Therefore, the total month difference is 504 - 2 = 502 months.
#
# 4. **Calculate Day Difference**: Now, we need to consider the days:
#    - From September 8 to November 20, we have:
#      - Days remaining in September after the 8th = 22 days (30 - 8 = 22).
#      - All days in October = 31 days.
#      - Days in November up to the 20th = 20 days.
#    - Total days = 22 (September) + 31 (October) + 20 (November) = 73 days.
#
# 5. **Compile Results**: Now we compile the results:
#    - Years: 42 years
#    - Months: 11 months (since we have 502 months, we convert this to years and months: 502 months = 41 years and 10 months, so we have 42 years and 11 months)
#    - Days: 12 days (since we have 73 days, we convert this to months and days: 73 days = 2 months and 13 days, so we have 11 months and 12 days)
#
# Thus, the final difference between Hypólito and Joe Biden's birth dates is 42 years, 11 months, and 12 days.
#
# Calling function get_plan_step with parameters {}
# Next Step: Convert both birth dates into a standard date format for calculation.
#
# > {'output_1': 'My next step should be: Convert both birth dates into a standard date format for calculation.'}
#
# Observation: I have gathered the birth dates of both Hypólito (September 8, 1984) and Joe Biden (November 20, 1942) and calculated the difference between their birth dates in years, months, and days. The final result shows a difference of 42 years, 11 months, and 12 days.
# Thoughts: Since the calculation of the difference in birth dates is complete, the next step is to present this information to the user in a clear and concise manner.
# Subtask identified: End Task
# Task completed successfully!
# [{'output_1': ["Calculate the difference in years between Hypólito and Joe Biden's birth dates.",
#    'Calculate the difference in months, adjusting for any partial years.',
#    'Calculate the difference in days, adjusting for any partial months.',
#    'Compile the results into a final format showing the difference in years, months, and days.']},
#  {'output_1': 'My next step should be: Research and find the birth date of Hypólito.'},
#  {'output_1': 'Results from first data source: Daniele Matias Hypólito (born 8 September 1984) is a Brazilian gymnast who competed in five Olympic Games from 2000 to 2016. She was the first Brazilian gymnast to win a World Championships medal, a silver in floor exercise in 2001, and is a nine-time senior all-around national champion. Hypólito has represented Brazil at the World Championships thirteen times and is the sister of Diego Hypólito, the first Brazilian male gymnast to win a World Championships medal.Results from second data source: Daniele Matias Hypólito (born 8 September 1985) is a Brazilian gymnast who competed in five Olympic Games from 2000 to 2015. She was the first Brazilian gymnast to win a World Championships medal, a silver in floor exercise in 2000, and is a nine-time senior all-around national champion. Hypólito has represented Brazil at the World Championships twelve times and is the sister of Diego Hypólito, the first Brazilian male gymnast to win a World Championships medal.Results from third data source: Daniele Matias Hypólito (born 8 October 1984) is a Brazilian gymnast who competed in four Olympic Games from 2000 to 2012. She was the first Brazilian gymnast to win a World Championships medal, a bronze in floor exercise in 2001, and is a ten-time senior all-around national champion. Hypólito has represented Brazil at the World Championships twelve times and is the sister of Diego Hypólito, the first Brazilian male gymnast to win a World Championships gold medal.'},
#  {'output_1': "My next step should be: Identify Joe Biden's birth date, which is known to be November 20, 1942."},
#  "To calculate the difference in years, months, and days between Hypólito's birth date (September 8, 1984) and Joe Biden's birth date (November 20, 1942), we follow these steps:\n\n1. **Convert Birth Dates**: Hypólito was born on September 8, 1984, and Joe Biden was born on November 20, 1942.\n\n2. **Calculate Year Difference**: From 1942 to 1984, the difference is 42 years. However, since we need to check the months and days, we will adjust this later.\n\n3. **Calculate Month Difference**: From November 1942 to September 1984, we have:\n   - Full years from November 1942 to November 1984 = 42 years = 42 * 12 = 504 months.\n   - From November 1984 to September 1984, we subtract 2 months (October and November).\n   - Therefore, the total month difference is 504 - 2 = 502 months.\n\n4. **Calculate Day Difference**: Now, we need to consider the days:\n   - From September 8 to November 20, we have:\n     - Days remaining in September after the 8th = 22 days (30 - 8 = 22).\n     - All days in October = 31 days.\n     - Days in November up to the 20th = 20 days.\n   - Total days = 22 (September) + 31 (October) + 20 (November) = 73 days.\n\n5. **Compile Results**: Now we compile the results:\n   - Years: 42 years\n   - Months: 11 months (since we have 502 months, we convert this to years and months: 502 months = 41 years and 10 months, so we have 42 years and 11 months)\n   - Days: 12 days (since we have 73 days, we convert this to months and days: 73 days = 2 months and 13 days, so we have 11 months and 12 days)\n\nThus, the final difference between Hypólito and Joe Biden's birth dates is 42 years, 11 months, and 12 days.",
#  {'output_1': 'My next step should be: Convert both birth dates into a standard date format for calculation.'}]

# %%
agent.status()
# Out:
# Agent Name: Reasoning Agent
# Agent Description: Generalized reasoning agent that solves tasks using reasoning modules step by step
# Available Functions: ['use_llm', 'end_task', 'get_knowledge']
# Shared Variables: ['agent', 'plan', 'current_step']
# Task: What is Hypólito's birth date and how far away is it from Joe Biden's in years, months and days?
# Subtasks Completed:
# Subtask: self_discover()
# {'output_1': ["Calculate the difference in years between Hypólito and Joe Biden's birth dates.", 'Calculate the difference in months, adjusting for any partial years.', 'Calculate the difference in days, adjusting for any partial months.', 'Compile the results into a final format showing the difference in years, months, and days.']}
#
# Subtask: get_plan_step()
# {'output_1': 'My next step should be: Research and find the birth date of Hypólito.'}
#
# Subtask: get_knowledge(search_query="Hypólito birth date")
# {'output_1': 'Results from first data source: Daniele Matias Hypólito (born 8 September 1984) is a Brazilian gymnast who competed in five Olympic Games from 2000 to 2016. She was the first Brazilian gymnast to win a World Championships medal, a silver in floor exercise in 2001, and is a nine-time senior all-around national champion. Hypólito has represented Brazil at the World Championships thirteen times and is the sister of Diego Hypólito, the first Brazilian male gymnast to win a World Championships medal.Results from second data source: Daniele Matias Hypólito (born 8 September 1985) is a Brazilian gymnast who competed in five Olympic Games from 2000 to 2015. She was the first Brazilian gymnast to win a World Championships medal, a silver in floor exercise in 2000, and is a nine-time senior all-around national champion. Hypólito has represented Brazil at the World Championships twelve times and is the sister of Diego Hypólito, the first Brazilian male gymnast to win a World Championships medal.Results from third data source: Daniele Matias Hypólito (born 8 October 1984) is a Brazilian gymnast who competed in four Olympic Games from 2000 to 2012. She was the first Brazilian gymnast to win a World Championships medal, a bronze in floor exercise in 2001, and is a ten-time senior all-around national champion. Hypólito has represented Brazil at the World Championships twelve times and is the sister of Diego Hypólito, the first Brazilian male gymnast to win a World Championships gold medal.'}
#
# Subtask: get_plan_step()(2)
# {'output_1': "My next step should be: Identify Joe Biden's birth date, which is known to be November 20, 1942."}
#
# Subtask: Calculate the difference in years, months, and days between Hypólito's birth date (September 8, 1984) and Joe Biden's birth date (November 20, 1942).
# To calculate the difference in years, months, and days between Hypólito's birth date (September 8, 1984) and Joe Biden's birth date (November 20, 1942), we follow these steps:
#
# 1. **Convert Birth Dates**: Hypólito was born on September 8, 1984, and Joe Biden was born on November 20, 1942.
#
# 2. **Calculate Year Difference**: From 1942 to 1984, the difference is 42 years. However, since we need to check the months and days, we will adjust this later.
#
# 3. **Calculate Month Difference**: From November 1942 to September 1984, we have:
#    - Full years from November 1942 to November 1984 = 42 years = 42 * 12 = 504 months.
#    - From November 1984 to September 1984, we subtract 2 months (October and November).
#    - Therefore, the total month difference is 504 - 2 = 502 months.
#
# 4. **Calculate Day Difference**: Now, we need to consider the days:
#    - From September 8 to November 20, we have:
#      - Days remaining in September after the 8th = 22 days (30 - 8 = 22).
#      - All days in October = 31 days.
#      - Days in November up to the 20th = 20 days.
#    - Total days = 22 (September) + 31 (October) + 20 (November) = 73 days.
#
# 5. **Compile Results**: Now we compile the results:
#    - Years: 42 years
#    - Months: 11 months (since we have 502 months, we convert this to years and months: 502 months = 41 years and 10 months, so we have 42 years and 11 months)
#    - Days: 12 days (since we have 73 days, we convert this to months and days: 73 days = 2 months and 13 days, so we have 11 months and 12 days)
#
# Thus, the final difference between Hypólito and Joe Biden's birth dates is 42 years, 11 months, and 12 days.
#
# Subtask: get_plan_step()(3)
# {'output_1': 'My next step should be: Convert both birth dates into a standard date format for calculation.'}
#
# Is Task Completed: True
