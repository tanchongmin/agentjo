# %% [markdown]
# # Advanced Tutorial 1 - Adding hooks to customise Agent Flow
#
# Created by: Sebbecht (Sebestian)
#
# Last Modified: 24 Jan 2025
#
# Before you dive into this tutorial, we recommend you work through the main tutorials first, as understanding the overall design philosophy and behavior of AgentJo is crucial to effectively customizing it.
#
# Suitable for adding Planners, Reflectors, Critics, Reasoning and many more
#
# ## Base Agent Behavior:
# When you execute a task using an AgentJo agent with agent.run(task), the agent will attempt to do the task step-by-step by identifying subtasks and executing them, using its available tools and its LLM.
# Specifically, the agent will execute the following steps for each number of allowed number of subtasks:
# * **self.get_next_subtask()** - this infers what tool to use to solve the subtask and what input to provide to the tool, if any.
# * **self.use_function(tool,input)** - this uses the tool with the input to solve the subtask.
# * if necessary, **self.summarise_subtasks_completed()** - this summarises the subtasks completed to maintain a low volume but high quality context in the agent's memory.
#
# ## Advanced Customization of Base Agent Behavior:
# Agents provide a way to wrap its base function with the forced execution of a list of functions before and after the base function.
# Based on the above base agent behavior, the primary base agent functions useful to wrap are run and get_next_subtask.
# * **run** - Add forced executions to BEFORE run if you want to execute functions after the task is assigned, but before any subtasks are initiated.
# * **run** - Add forced executions to AFTER run if you want to execute functions after the subtasks are completed, but before the final output is returned.
# * **get_next_subtask** - Add forced executions to BEFORE get_next_subtask if you want to execute functions before the next tool is inferred. NOTE: If subtasks have already been completed at this point in the loop, this is equal to AFTER use_function
# * **get_next_subtask** - Add forced executions to AFTER get_next_subtask if you want to execute functions after the next tool is inferred (note at this point, the tool is identified with inputs, but not used yet)
#
# Note: use_function cannot be wrapped as it will cause infinite loops.
#
# ## Design Philosophy:
# * The base agent behavior is simple but powerful. It approaches tasks step-by-step by using a "observe", "thought", "act" pattern.
# * All assigned tools are effectively optional and the agent will infer the best tool to use to solve the subtask.
# * AgentJo provides you with this wrapping utility to allow you to modify and extend the base agent behavior. All functions you use for wrapping are executed forcefully in the order you specify - this allows you to structurally modify the agent's behavior.
#
# ## Conceptual Examples:
# These examples are not exhaustive, but they illustrate the conceptual utility
# * Adding self-reflection to the agent's behavior: insert a reflection function to be executed BEFORE and/or AFTER get_next_subtask - this allows the agent to utilize an extra reflection step after each subtask is completed.
# * Adding a critic: insert a critic function to be executed BEFORE and/or AFTER get_next_subtask - This critic could guardrail the agent's behavior and ensure it is following a rule-set for example.
# * Extended reasoning structures: Force the agent to use reasoning modules to solve the task by inserting a reasoning module function to be executed BEFORE run.
#
# ## In this tutorial we will implement the following:
# * Adding self-reflection to the agent's behavior
# * Expanding the reasoning structure to follow a Self-Discover framework

# %%
from agentjo import *

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
def llm(system_prompt: str, user_prompt: str) -> str:
    ''' Here, we use OpenAI for illustration, you can change it to your own LLM '''
    # ensure your LLM imports are all within this function
    from openai import OpenAI
    
    # define your own LLM here
    client = OpenAI()
    response = client.chat.completions.create(
        model='gpt-4o-mini',
        temperature = 0,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ]
    )
    return response.choices[0].message.content

# %% [markdown]
# ## For illustration purposes we will use the wikipedia tool and ask the agent to answer a question. To run this tutorial, you need to install the wikipedia package

# %%
# !pip install wikipedia langchain_community

# %%
def wikipedia_tool(search_query: str) -> str:
    ''' Uses search_query and returns text from wikipedia. Do not include site:wikipedia.org in the search_query'''
    from langchain.tools import WikipediaQueryRun
    from langchain.utilities import WikipediaAPIWrapper

    return WikipediaQueryRun(api_wrapper=WikipediaAPIWrapper()).run(search_query)

agent = Agent('Question Answerer', 
              'Answers a question factually. If the search results are not good, refine search and search again',
              llm = llm).assign_functions([wikipedia_tool])


agent.run("What is Hypólito's birth date and how far away is it from Joe Biden's in years, months and days?")

agent.reply_user("Reply only the answer without explanation")
# Out:
# Observation: The task requires finding Hypólito's birth date and calculating the time difference from Joe Biden's birth date in years, months, and days. No subtasks have been completed yet.
#
# Thoughts: To complete the task, I need to first find Hypólito's birth date using a reliable source. Once I have that information, I can then find Joe Biden's birth date and calculate the difference between the two dates.
#
# Subtask identified: Use the wikipedia_tool to search for Hypólito's birth date.
#
# Calling function wikipedia_tool with parameters {'search_query': 'Hypólito birth date'}
# > {'output_1': "Page: Daniele Hypólito\nSummary: Daniele Matias Hypólito (born 8 September 1984) is a Brazilian gymnast who competed at the 2000, 2004, 2008, 2012 and the 2016 Olympic Games. Hypólito is the first gymnast from Brazil to win a medal at the World Championships, a silver in floor exercise in 2001. She is also the nine-time senior all-around Brazilian national champion in artistic gymnastics, 2002 South American Games all-around champion and 2003 Pan American Games all-around bronze medalist. To date, Hypólito has won the Brazilian National Championships more than ten times; represented Brazil at the World Championships thirteen times, competing in every championship from 1999 to 2015, except in 2009; taken part in every edition of the Olympic Games from 2000 to 2016; and competed at five Pan American Games between 1999 and 2015.\nShe is the sister of Diego Hypólito, the first Brazilian male gymnast to win a medal at the World Championships.\n\n\n\nPage: Rebeca Andrade\nSummary: Rebeca Rodrigues de Andrade (Brazilian Portuguese pronunciation: [ʁeˈbɛkɐ ʁoˈdɾiɡis dʒi ɐ̃ˈdɾadʒi]; born 8 May 1999) is a Brazilian artistic gymnast. Having won a total of six Olympic and nine World medals, she is the most decorated Brazilian and Latin American gymnast of all time, as well as the most decorated Brazilian Olympian in any discipline. In the all-around, she is the 2022 World champion, a two-time Olympic silver medalist (2020, 2024), the 2023 World silver medalist, and the 2021 Pan American champion. On vault, she is the 2020 Olympic gold medalist, the 2024 Olympic silver medalist, a two-time World Champion (2021, 2023), and the 2023 Pan American Games champion. In the floor exercise, she is the 2024 Olympic gold medalist, 2023 World silver medallist, and 2022 World bronze medallist. She led the Brazilian team to its first ever team medals at the 2023 World Championships (silver) and the 2024 Olympics (bronze), as well as the gold medal at the 2021 Pan American Championships. \nAndrade is the first Brazilian female gymnast to medal at an Olympic Games and only the second Brazilian woman to win a gold medal at the World Artistic Gymnastics Championships. Andrade is one of only 11 female gymnasts to have medalled on every event in the history of World Championships, and one of only three gymnasts to have done so in the 21st century, alongside Simone Biles and Aliya Mustafina.\nAt the junior level, she is the 2012 Junior Pan American champion in the all-around and on vault and floor exercise, and the 2014 Junior Pan American champion on the vault, uneven bars, and balance beam. After a successful junior career, Andrade's senior debut in 2015 was cut short by the first of three ACL tears. She returned to competition and represented Brazil at the 2016 Summer Olympics, where she placed eleventh in the all-around final. She tore her ACL for the second time in 2017, but made her World Championships debut in 2018. After her third ACL tear in 2019, Andrade represented Brazil at the 2020 Summer Olympics and at the 2021 World Championships, where she won the vault gold medal at both events.\n\n\n\nPage: List of athletes with the most appearances at Olympic Games\nSummary: Only a small fraction of the world's population ever competes at the Olympic Games; an even smaller fraction competes in multiple Games. 950 athletes (648 men and 302 women) have participated in at least five Olympics from Athens 1896 to Paris 2024, but excluding the 1906 Intercalated Games. 229 of these have gone on to make at least a sixth Olympic appearance."}
#
# Observation: Daniele Hypólito was born on 8 September 1984. The next step is to find Joe Biden's birth date to calculate the difference in years, months, and days.
#
# Thoughts: I need to find Joe Biden's birth date, which is 20 November 1942. Once I have both birth dates, I can calculate the difference between them in years, months, and days.
#
# Subtask identified: Calculate the difference between 8 September 1984 and 20 November 1942 in years, months, and days.
#
# Getting LLM to perform the following task: Calculate the difference between 8 September 1984 and 20 November 1942 in years, months, and days.
#
# > To calculate the difference between 8 September 1984 and 20 November 1942, we can break it down into years, months, and days.
#
# 1. **Years**: From 20 November 1942 to 20 November 1984 is 42 years.
# 2. **Months**: From 20 November 1984 to 8 September 1984, we need to go back to the previous year, which gives us 10 months (from November to September).
# 3. **Days**: From 20 September to 8 September is 12 days.
#
# Therefore, the total difference is 41 years, 10 months, and 18 days.
#
#
# Observation: Hypólito was born on 8 September 1984. The difference between her birth date and Joe Biden's birth date (20 November 1942) has been calculated as 41 years, 10 months, and 18 days.
#
# Thoughts: To complete the remainder of the Assigned Task, I need to present the calculated difference in a clear and concise manner, ensuring that it is easy to understand for the user.
#
# Subtask identified: End Task
# Task completed successfully!
# 'Daniele Matias Hypólito was born on 8 September 1984. The difference between her birth date and 20 November 1942 is 41 years, 10 months, and 18 days.\n'

# %% [markdown]
# ## Lets use the wrap_function utility to add self-reflection to the agent's behavior. This is an extra "reasoning" step along-side the agents normal "Observe", "Think" and "Act" steps.
# We will insert it before get_next_subtask so that it is used during the subtask inference process.

# %%
from termcolor import colored
def reflect(shared_variables) -> str:
    '''Produces a thought about the task'''
    agent = shared_variables['agent']
    res = parse_yaml(system_prompt = f'''Reflect on the progress towards your main task {agent.overall_task} \n Subtasks Completed: ```{agent.subtasks_completed}```''',
                        user_prompt = '',
                        output_format = {'Progress': 'Your reflections on the progress towards your main task in one short sentence, type: str'},
                        llm = llm)
    print(colored(f"Reflection: {res['Progress']} \n"  ,'red',attrs=['bold']))
    shared_variables['reflection'] = res['Progress']
    return res['Progress']

agent = Agent('Question Answerer', 
              'Answers a question factually. If the search results are not good, refine search and search again',
              llm = llm).assign_functions([wikipedia_tool])

agent.wrap_function(func='get_next_subtask',before_hook = [reflect])

agent.run("What is Hypólito's birth date and how far away is it from Joe Biden's in years, months and days?")

agent.reply_user("Reply only the answer without explanation")
# Out:
# Calling function reflect with parameters {}
# /opt/anaconda3/lib/python3.12/site-packages/strictjson/parse_yaml.py:163: UserWarning: LLM Parsing failed at attempt 1.
# Retrying...
#   warnings.warn(my_warning, UserWarning)
# Reflection: I have not yet determined Hypólito's birth date or calculated the time difference from Joe Biden.
#
# > {'output_1': "I have not yet determined Hypólito's birth date or calculated the time difference from Joe Biden."}
#
# Observation: I have not yet determined Hypólito's birth date or calculated the time difference from Joe Biden.
#
# Thoughts: I need to find Hypólito's birth date first. Once I have that information, I can then calculate the time difference between his birth date and Joe Biden's birth date.
#
# Subtask identified: Use the wikipedia_tool to search for Hypólito's birth date.
#
# Calling function wikipedia_tool with parameters {'search_query': 'Hypólito birth date'}
# > {'output_1': "Page: Daniele Hypólito\nSummary: Daniele Matias Hypólito (born 8 September 1984) is a Brazilian gymnast who competed at the 2000, 2004, 2008, 2012 and the 2016 Olympic Games. Hypólito is the first gymnast from Brazil to win a medal at the World Championships, a silver in floor exercise in 2001. She is also the nine-time senior all-around Brazilian national champion in artistic gymnastics, 2002 South American Games all-around champion and 2003 Pan American Games all-around bronze medalist. To date, Hypólito has won the Brazilian National Championships more than ten times; represented Brazil at the World Championships thirteen times, competing in every championship from 1999 to 2015, except in 2009; taken part in every edition of the Olympic Games from 2000 to 2016; and competed at five Pan American Games between 1999 and 2015.\nShe is the sister of Diego Hypólito, the first Brazilian male gymnast to win a medal at the World Championships.\n\n\n\nPage: Rebeca Andrade\nSummary: Rebeca Rodrigues de Andrade (Brazilian Portuguese pronunciation: [ʁeˈbɛkɐ ʁoˈdɾiɡis dʒi ɐ̃ˈdɾadʒi]; born 8 May 1999) is a Brazilian artistic gymnast. Having won a total of six Olympic and nine World medals, she is the most decorated Brazilian and Latin American gymnast of all time, as well as the most decorated Brazilian Olympian in any discipline. In the all-around, she is the 2022 World champion, a two-time Olympic silver medalist (2020, 2024), the 2023 World silver medalist, and the 2021 Pan American champion. On vault, she is the 2020 Olympic gold medalist, the 2024 Olympic silver medalist, a two-time World Champion (2021, 2023), and the 2023 Pan American Games champion. In the floor exercise, she is the 2024 Olympic gold medalist, 2023 World silver medallist, and 2022 World bronze medallist. She led the Brazilian team to its first ever team medals at the 2023 World Championships (silver) and the 2024 Olympics (bronze), as well as the gold medal at the 2021 Pan American Championships. \nAndrade is the first Brazilian female gymnast to medal at an Olympic Games and only the second Brazilian woman to win a gold medal at the World Artistic Gymnastics Championships. Andrade is one of only 11 female gymnasts to have medalled on every event in the history of World Championships, and one of only three gymnasts to have done so in the 21st century, alongside Simone Biles and Aliya Mustafina.\nAt the junior level, she is the 2012 Junior Pan American champion in the all-around and on vault and floor exercise, and the 2014 Junior Pan American champion on the vault, uneven bars, and balance beam. After a successful junior career, Andrade's senior debut in 2015 was cut short by the first of three ACL tears. She returned to competition and represented Brazil at the 2016 Summer Olympics, where she placed eleventh in the all-around final. She tore her ACL for the second time in 2017, but made her World Championships debut in 2018. After her third ACL tear in 2019, Andrade represented Brazil at the 2020 Summer Olympics and at the 2021 World Championships, where she won the vault gold medal at both events.\n\n\n\nPage: List of athletes with the most appearances at Olympic Games\nSummary: Only a small fraction of the world's population ever competes at the Olympic Games; an even smaller fraction competes in multiple Games. 950 athletes (648 men and 302 women) have participated in at least five Olympics from Athens 1896 to Paris 2024, but excluding the 1906 Intercalated Games. 229 of these have gone on to make at least a sixth Olympic appearance."}
#
# Calling function reflect with parameters {}
# Reflection: I have found Hypólito's birth date as 8 September 1984, but I still need to calculate the time difference from Joe Biden's birth date.
#
#
# > {'output_1': "I have found Hypólito's birth date as 8 September 1984, but I still need to calculate the time difference from Joe Biden's birth date.\n"}
#
# Observation: I have found Hypólito's birth date as 8 September 1984, but I still need to calculate the time difference from Joe Biden's birth date.
#
# Thoughts: To complete the remainder of the Assigned Task, I need to find Joe Biden's birth date, which is 20 November 1942, and then calculate the difference in years, months, and days between his birth date and Hypólito's birth date.
#
# Subtask identified: Calculate the time difference between Hypólito's birth date (8 September 1984) and Joe Biden's birth date (20 November 1942) in years, months, and days.
#
# Getting LLM to perform the following task: Calculate the time difference between Hypólito's birth date (8 September 1984) and Joe Biden's birth date (20 November 1942) in years, months, and days.
#
# > To calculate the time difference between Hypólito's birth date (8 September 1984) and Joe Biden's birth date (20 November 1942), we first determine the years, months, and days between the two dates.
#
# 1. **Years**: From 1942 to 1984 is 42 years.
# 2. **Months**: From November to September is 10 months (since we are counting backwards).
# 3. **Days**: From the 20th to the 8th of September is 18 days.
#
# Therefore, the total time difference is 42 years, 10 months, and 18 days.
#
#
# Calling function reflect with parameters {}
# Reflection: I have successfully found Hypólito's birth date and calculated the time difference from Joe Biden's birth date.
#
#
# > {'output_1': "I have successfully found Hypólito's birth date and calculated the time difference from Joe Biden's birth date.\n"}
#
# Observation: I have successfully found Hypólito's birth date as 8 September 1984 and calculated the time difference from Joe Biden's birth date as 42 years, 10 months, and 18 days.
#
# Thoughts: Since I have completed the calculations, I can now summarize the findings and present the final output to the user.
#
# Subtask identified: End Task
# Task completed successfully!
# "Hypólito's birth date is 8 September 1984. The time difference from Joe Biden's birth date (20 November 1942) is 42 years, 10 months, and 18 days.\n"

# %% [markdown]
# ## Let's alter the wikipedia tool with some trickery to make it more interesting and harder to solve
# * We will still search wikipedia, but we will also slightly alter the results to make them false
# * Now the agent will have to do some more work to determine which results are true and which are false

# %%
def get_knowledge(search_query: str) -> str:
    ''' Uses search_query to search three different data sources and returns the results for each data source'''
    from langchain.tools import WikipediaQueryRun
    from langchain.utilities import WikipediaAPIWrapper

    results_str = ""
    
    original_results =  WikipediaQueryRun(api_wrapper=WikipediaAPIWrapper()).run(search_query)

    response = parse_yaml(system_prompt = f'''Summarizer and shorten the results based on the search query without losing information about what the query was, but still include other irrelevant facts

                           The original query was: 
                           {search_query}
                           Original truthful answer:
                           {original_results}
                            ''',
                    user_prompt = '',
                    output_format = {'Summarized Results': 'Your summarized answer, type: str'},
                    llm = llm)
    
    original_results = response['Summarized Results']
    print(colored(f"Summarized Results: {original_results} \n",'magenta',attrs=['bold']))

    #results from first data source
    results_str += f"Results from first data source: {original_results}"

    # First corruption of original results
    response = parse_yaml(system_prompt = f'''You are a player in a game of deception. Another player asked a question and was given a truthful answer.
                           Your part of the game is to slightly alter the truthful answer to make it different from the original answer. You are only allowed to alter numbers and dates, no text.
                           Make smaller alterations which result in counterfactuals or counterintuitive results. Keep the structure of the results the same.
                           The original query was: 
                           {search_query}
                           Original truthful answer:
                           {original_results}
                            ''',
                    user_prompt = '',
                    output_format = {'Corrupted Results': 'Your corrupted answer, type: str'},
                    llm = llm)
    
    corrupted_results = response['Corrupted Results']
    print(colored(f"Results from second data source: {corrupted_results} \n",'magenta',attrs=['bold']))

    #results from second data source
    results_str += f"Results from second data source: {corrupted_results}"

    # Second corruption of original results
    response = parse_yaml(system_prompt = f'''You are a player in a game of deception. You are given a truthful answer.
                           Your part of the game is to slightly alter the truthful answer to make it different from the original answer. 
                           You are only allowed to alter text, not numbers or dates.
                           For example, alter placenames, and other 
                           Make smaller alterations which result in counterfactuals or counterintuitive results. Keep the structure of the results the same.
                           The original query was: 
                           {search_query}
                           Original truthful answer:
                           {original_results}
                            ''',
                    user_prompt = '',
                    output_format = {'Corrupted Results': 'Your corrupted answer, type: str'},
                    llm = llm)
    
    corrupted_results = response['Corrupted Results']

    results_str += f"Results from third data source: {corrupted_results}"
    print(colored(f"Results from third data source: {corrupted_results} \n",'magenta',attrs=['bold']))

    return results_str

# %%
agent = Agent('Question Answerer', 
              'Answers a question factually. If the search results are not good, refine search and search again',
              llm = llm).assign_functions([get_knowledge])


agent.run("What is Hypólito's birth date and how far away is it from Joe Biden's in years, months and days?")

agent.reply_user("Reply only the answer without explanation")
# Out:
# Observation: No subtasks have been completed yet for the assigned task of finding Hypólito's birth date and calculating the time difference from Joe Biden's birth date.
#
# Thoughts: To complete the remainder of the assigned task, I need to first find Hypólito's birth date. Once I have that information, I can then look up Joe Biden's birth date and calculate the difference in years, months, and days.
#
# Subtask identified: Search for Hypólito's birth date using the equipped function.
#
# Calling function get_knowledge with parameters {'search_query': 'Hypólito birth date'}
# Summarized Results: Daniele Matias Hypólito was born on 8 September 1984. She is a Brazilian gymnast who competed in five Olympic Games (2000, 2004, 2008, 2012, 2016) and is the first Brazilian gymnast to win a World Championships medal. She has won the Brazilian National Championships over ten times and is the sister of Diego Hypólito.
#
#
# Results from second data source: Daniele Matias Hypólito was born on 9 September 1985. She is a Brazilian gymnast who competed in five Olympic Games (2001, 2005, 2009, 2013, 2017) and is the first Brazilian gymnast to win a World Championships medal. She has won the Brazilian National Championships over nine times and is the sister of Diego Hypólito.
#
# Results from third data source: Daniele Matias Hypólito was born on 8 September 1984. She is a gymnast from Brazil who participated in five Olympic Games (2000, 2004, 2008, 2012, 2016) and is recognized as the first Brazilian gymnast to earn a medal at the World Championships. She has claimed the Brazilian National Championships more than ten times and is the sibling of Diego Hypólito.
#
#
# > {'output_1': 'Results from first data source: Daniele Matias Hypólito was born on 8 September 1984. She is a Brazilian gymnast who competed in five Olympic Games (2000, 2004, 2008, 2012, 2016) and is the first Brazilian gymnast to win a World Championships medal. She has won the Brazilian National Championships over ten times and is the sister of Diego Hypólito. \nResults from second data source: Daniele Matias Hypólito was born on 9 September 1985. She is a Brazilian gymnast who competed in five Olympic Games (2001, 2005, 2009, 2013, 2017) and is the first Brazilian gymnast to win a World Championships medal. She has won the Brazilian National Championships over nine times and is the sister of Diego Hypólito.Results from third data source: Daniele Matias Hypólito was born on 8 September 1984. She is a gymnast from Brazil who participated in five Olympic Games (2000, 2004, 2008, 2012, 2016) and is recognized as the first Brazilian gymnast to earn a medal at the World Championships. She has claimed the Brazilian National Championships more than ten times and is the sibling of Diego Hypólito.\n'}
#
# Observation: Daniele Matias Hypólito was born on 8 September 1984 according to two sources, while one source states her birth date as 9 September 1985. This discrepancy needs to be resolved to accurately calculate the time difference from Joe Biden's birth date.
#
# Thoughts: I need to confirm the correct birth date of Daniele Matias Hypólito and then find Joe Biden's birth date, which is 20 November 1942. After confirming Hypólito's birth date, I can calculate the difference in years, months, and days between the two dates.
#
# Subtask identified: Confirm the correct birth date of Daniele Matias Hypólito by refining the search and checking additional sources.
#
# Calling function get_knowledge with parameters {'search_query': 'Daniele Matias Hypólito birth date'}
# Summarized Results: Daniele Matias Hypólito (born 8 September 1984) is a Brazilian gymnast who competed in five Olympic Games from 2000 to 2016. She was the first Brazilian gymnast to win a World Championships medal, a silver in 2001, and is a nine-time senior all-around national champion. Hypólito has also won multiple medals at the South American and Pan American Games. She is the sister of Diego Hypólito, the first Brazilian male gymnast to win a World Championships medal.
#
#
# Results from second data source: Daniele Matias Hypólito (born 9 September 1985) is a Brazilian gymnast who competed in five Olympic Games from 2001 to 2017. She was the first Brazilian gymnast to win a World Championships medal, a silver in 2002, and is a ten-time senior all-around national champion. Hypólito has also won multiple medals at the South American and Pan American Games. She is the sister of Diego Hypólito, the first Brazilian male gymnast to win a World Championships medal.
#
# Results from third data source: Daniele Matias Hypólito (born 8 October 1984) is a Brazilian gymnast who participated in five Olympic Games from 2000 to 2018. She was the first Brazilian gymnast to earn a World Championships medal, a bronze in 2001, and is a ten-time senior all-around national champion. Hypólito has also secured various medals at the South American and Pan American Championships. She is the sibling of Diego Hypólito, the first Brazilian male gymnast to achieve a World Championships medal.
#
# > {'output_1': 'Results from first data source: Daniele Matias Hypólito (born 8 September 1984) is a Brazilian gymnast who competed in five Olympic Games from 2000 to 2016. She was the first Brazilian gymnast to win a World Championships medal, a silver in 2001, and is a nine-time senior all-around national champion. Hypólito has also won multiple medals at the South American and Pan American Games. She is the sister of Diego Hypólito, the first Brazilian male gymnast to win a World Championships medal.\nResults from second data source: Daniele Matias Hypólito (born 9 September 1985) is a Brazilian gymnast who competed in five Olympic Games from 2001 to 2017. She was the first Brazilian gymnast to win a World Championships medal, a silver in 2002, and is a ten-time senior all-around national champion. Hypólito has also won multiple medals at the South American and Pan American Games. She is the sister of Diego Hypólito, the first Brazilian male gymnast to win a World Championships medal.Results from third data source: Daniele Matias Hypólito (born 8 October 1984) is a Brazilian gymnast who participated in five Olympic Games from 2000 to 2018. She was the first Brazilian gymnast to earn a World Championships medal, a bronze in 2001, and is a ten-time senior all-around national champion. Hypólito has also secured various medals at the South American and Pan American Championships. She is the sibling of Diego Hypólito, the first Brazilian male gymnast to achieve a World Championships medal.'}
#
# Observation: There are conflicting birth dates for Daniele Matias Hypólito: 8 September 1984 and 9 September 1985.
# The majority of sources indicate 8 September 1984 as the correct date.
# Joe Biden was born on 20 November 1942.
#
# Thoughts: To determine the time difference between Hypólito's birth date and Joe Biden's,
# I need to confirm the correct birth date for Hypólito and then calculate the difference in years, months, and days.
#
# Subtask identified: Calculate the difference in years, months, and days between 8 September 1984 and 20 November 1942.
#
# Getting LLM to perform the following task: Calculate the difference in years, months, and days between 8 September 1984 and 20 November 1942.
#
# > To calculate the difference between 8 September 1984 and 20 November 1942, we can break it down into years, months, and days.
#
# 1. **Years**: From 1942 to 1984 is 42 years.
# 2. **Months**: From November to September is 10 months (since we are not counting the month of September in 1984).
# 3. **Days**: From the 20th to the 8th of September, we need to account for the days in the months:
#    - November has 30 days, so from the 20th to the end of November is 10 days.
#    - December has 31 days.
#    - January has 31 days.
#    - February has 29 days (1984 is a leap year).
#    - March has 31 days.
#    - April has 30 days.
#    - May has 31 days.
#    - June has 30 days.
#    - July has 31 days.
#    - August has 31 days.
#    - From 1st to 8th of September is 8 days.
#
#    Adding these days together:
#    - 10 (November) + 31 (December) + 31 (January) + 29 (February) + 31 (March) + 30 (April) + 31 (May) + 30 (June) + 31 (July) + 31 (August) + 8 (September) = 10 + 31 + 31 + 29 + 31 + 30 + 31 + 30 + 31 + 31 + 8 =  10 + 31*7 + 29 + 8 = 10 + 217 + 29 + 8 = 264 days.
#
# Therefore, the total difference is:
# - **42 years, 10 months, and 264 days**.
#
#
# Observation: Daniele Matias Hypólito was born on 8 September 1984 according to the first and third data sources, while the second data source states her birth date as 9 September 1985. Joe Biden was born on 20 November 1942. The difference in time between these two dates has been calculated as 42 years, 10 months, and 264 days.
#
# Thoughts: To finalize the task, I need to confirm the correct birth date of Daniele Matias Hypólito and ensure the difference in years, months, and days is accurately presented. Since there are conflicting birth dates, I should use the most reliable source, which appears to be the first and third data sources that state her birth date as 8 September 1984.
#
# Subtask identified: End Task
# Task completed successfully!
# 'Daniele Matias Hypólito was born on 8 September 1984 according to multiple sources, while another source states her birth date as 9 September 1985. She is a Brazilian gymnast who competed in five Olympic Games (2000, 2004, 2008, 2012, 2016) and is recognized as the first Brazilian gymnast to earn a medal at the World Championships. She has won the Brazilian National Championships over ten times and is the sister of Diego Hypólito. The difference between 8 September 1984 and 20 November 1942 is 42 years, 10 months, and 264 days.\n'

# %% [markdown]
# As you can see, the agent is capable of determining that results differ and come to a decent conclusion on what to do, on the fly, given it only has access to these three data sources and no other tools.
#
# Assuming your agents will tackle even harder problems, you may want to implement a more elaborate reasoning framework to help them solve the problem.

# %% [markdown]
# ## Self-Discover
# Lets implement a reasoning framework called Self-Discover (with some changes to better fit AgentJo and parse_yaml)
# Paper: https://arxiv.org/pdf/2402.03620
#
# Self-Discover works as follows:
# * Select a reasoning module that is most relevant to the task from a list of seed reasoning modules - these are abstractly defined reasoning modules that are general to all tasks
# * Adapt the reasoning module to be specific to the task - this takes the abstract reasoning module and makes it specific to the task
# * Implement the reasoning module - this takes the adapted reasoning module and implements it
#
# This allows the agent to discover a reasoning approach. By using the wrap_function utility, we can force the agent to select, adapt and implement a reasoning module after the task is assigned and before the subtasks are initiated.
#
# In this example the prompts are slightly modified from the paper. The seed reasoning modules are the same.
#
# Note: strict_json / parse_yaml is actually exceptionally effective at implementing this framework as you want LLMs to be minimal verbose and maximally concise when following reasoning structures.

# %%
reasoning_modules = [
    "How could I devise an experiment to help solve that problem?",
    "Make a list of ideas for solving this problem, and apply them one by one to the problem to see if any progress can be made.",
    "How could I measure progress on this problem?",
    "How can I simplify the problem so that it is easier to solve?",
    "What are the key assumptions underlying this problem?",
    "What are the potential risks and drawbacks of each solution?",
    "What are the alternative perspectives or viewpoints on this problem?",
    "What are the long-term implications of this problem and its solutions?",
    "How can I break down this problem into smaller, more manageable parts?",
    "Critical Thinking: This style involves analyzing the problem from different perspectives, questioning assumptions, and evaluating the evidence or information available. It focuses on logical reasoning, evidence-based decision-making, and identifying potential biases or flaws in thinking.",
    "Try creative thinking, generate innovative and out-of-the-box ideas to solve the problem. Explore unconventional solutions, thinking beyond traditional boundaries, and encouraging imagination and originality.",
    "Seek input and collaboration from others to solve the problem. Emphasize teamwork, open communication, and leveraging the diverse perspectives and expertise of a group to come up with effective solutions.",
    "Use systems thinking: Consider the problem as part of a larger system and understanding the interconnectedness of various elements. Focuses on identifying the underlying causes, feedback loops, and interdependencies that influence the problem, and developing holistic solutions that address the system as a whole.",
    "Use Risk Analysis: Evaluate potential risks, uncertainties, and tradeoffs associated with different solutions or approaches to a problem. Emphasize assessing the potential consequences and likelihood of success or failure, and making informed decisions based on a balanced analysis of risks and benefits.",
    "Use Reflective Thinking: Step back from the problem, take the time for introspection and self-reflection. Examine personal biases, assumptions, and mental models that may influence problem-solving, and being open to learning from past experiences to improve future approaches.",
    "What is the core issue or problem that needs to be addressed?",
    "What are the underlying causes or factors contributing to the problem?",
    "Are there any potential solutions or strategies that have been tried before? If yes, what were the outcomes and lessons learned?",
    "What are the potential obstacles or challenges that might arise in solving this problem?",
    "Are there any relevant data or information that can provide insights into the problem? If yes, what data sources are available, and how can they be analyzed?",
    "Are there any stakeholders or individuals who are directly affected by the problem? What are their perspectives and needs?",
    "What resources (financial, human, technological, etc.) are needed to tackle the problem effectively?",
    "How can progress or success in solving the problem be measured or evaluated?",
    "What indicators or metrics can be used?",
    "Is the problem a technical or practical one that requires a specific expertise or skill set? Or is it more of a conceptual or theoretical problem?",
    "Does the problem involve a physical constraint, such as limited resources, infrastructure, or space?",
    "Is the problem related to human behavior, such as a social, cultural, or psychological issue?",
    "Does the problem involve decision-making or planning, where choices need to be made under uncertainty or with competing objectives?",
    "Is the problem an analytical one that requires data analysis, modeling, or optimization techniques?",
    "Is the problem a design challenge that requires creative solutions and innovation?",
    "Does the problem require addressing systemic or structural issues rather than just individual instances?",
    "Is the problem time-sensitive or urgent, requiring immediate attention and action?",
    "What kinds of solution typically are produced for this kind of problem specification?",
    "Given the problem specification and the current best solution, have a guess about other possible solutions."
    "Let’s imagine the current best solution is totally wrong, what other ways are there to think about the problem specification?"
    "What is the best way to modify this current best solution, given what you know about these kinds of problem specification?"
    "Ignoring the current best solution, create an entirely new solution to the problem."
    "Let’s think step by step."
    "Let’s make a step by step plan and implement it with good notation and explanation.",
]

# %%
def self_discover(shared_variables):
    task_description = shared_variables['agent'].overall_task
    response = parse_yaml(system_prompt = f'''Given the task: {task_description}, which reasoning module is most relevant?.

                    All reasoning module descriptions:
                    {reasoning_modules}

                    Task: {task_description}

                    Select one module that is crucial for solving the task above.''',
                    user_prompt = '',
                    output_format = {'Thoughts': 'Analyze the task and select an appropiate reasoning module, type: str',
                        'Selected Module': 'Your one selected module, type: str'},
                    llm = llm)
    selected_module = response['Selected Module']
    print(colored(f"Thoughts: {response['Thoughts']} \n",'red',attrs=['bold']))
    print(colored(f"Selected Reasoning Module: {response['Selected Module']} \n",'red',attrs=['bold']))
    
    response = parse_yaml(system_prompt = f'''Using the selected reasoning module:
                    {selected_module}

                    Create a step by step plan to put the reasoning module into action to solve the task:
                    {task_description}

                    Your thoughts so far are:
                    {response['Thoughts']}

                    ''',
                    user_prompt = '',
                    output_format = {'Plan': 'Your step by step plan as a list of steps, type: list[str]'},
                    llm = llm)
    shared_variables['plan'] = response['Plan']
    
    print(colored(f"Plan: {shared_variables['plan']} \n",'red',attrs=['bold']))
    return shared_variables['plan']

def get_plan_step(shared_variables):
    '''Get the next step of the plan'''
    plan = shared_variables['plan']
    step = plan.pop(0)
    shared_variables['plan'] = plan
    shared_variables['current_step'] = step
    print(colored(f"Next Step: {step} \n",'red',attrs=['bold']))
    return f"My next step should be: {step}"
   
agent = Agent('Reasoning Agent', 
              'Generalized reasoning agent that solves tasks using reasoning modules step by step',
              llm = llm).assign_functions([get_knowledge])

agent.wrap_function(func='run',before_hook = [self_discover])
agent.wrap_function(func='get_next_subtask',before_hook = [get_plan_step])

agent.run("What is Hypólito's birth date and how far away is it from Joe Biden's in years, months and days?")
# Out:
# Calling function self_discover with parameters {}
# Thoughts: Analyze the task and select an appropriate reasoning module, type: str
#
# Selected Reasoning Module: What are the key assumptions underlying this problem?
# /opt/anaconda3/lib/python3.12/site-packages/strictjson/parse_yaml.py:163: UserWarning: LLM Parsing failed at attempt 1.
# Retrying...
#   warnings.warn(my_warning, UserWarning)
# Plan: ["Identify Hypólito's birth date.", "Identify Joe Biden's birth date.", 'Calculate the difference in years between the two birth dates.', 'Calculate the difference in months between the two birth dates.', 'Calculate the difference in days between the two birth dates.', 'Present the final result in years, months, and days.']
#
# > {'output_1': ["Identify Hypólito's birth date.", "Identify Joe Biden's birth date.", 'Calculate the difference in years between the two birth dates.', 'Calculate the difference in months between the two birth dates.', 'Calculate the difference in days between the two birth dates.', 'Present the final result in years, months, and days.']}
#
# Calling function get_plan_step with parameters {}
# Next Step: Identify Hypólito's birth date.
#
# > {'output_1': "My next step should be: Identify Hypólito's birth date."}
#
# Observation: The subtasks completed indicate that I have identified Joe Biden's birth date and calculated the differences in years, months, and days between his birth date and Hypólito's. The next step is to identify Hypólito's birth date.
#
# Thoughts: To complete the remainder of the Assigned Task, I need to search for Hypólito's birth date. Once I have that information, I can calculate the differences in years, months, and days from Joe Biden's birth date.
#
# Subtask identified: Use the get_knowledge function to search for Hypólito's birth date.
#
# Calling function get_knowledge with parameters {'search_query': "What is Hypólito's birth date?"}
# /opt/anaconda3/lib/python3.12/site-packages/strictjson/parse_yaml.py:163: UserWarning: LLM Parsing failed at attempt 1.
# Retrying...
#   warnings.warn(my_warning, UserWarning)
# Summarized Results: The query was about Hypólito's birth date, but the search results did not provide that information. Instead, they included a list of LGBTQ sportspeople, details about Rebeca Andrade, a Brazilian gymnast born on 8 May 1999, and a partial list of notable gay, lesbian, or bisexual individuals, discussing the historical context of sexual orientation.
#
# Results from second data source: The query was about Hypólito's birth date, but the search results did not provide that information. Instead, they included a list of LGBTQ sportspeople, details about Rebeca Andrade, a Brazilian gymnast born on 9 May 1998, and a partial list of notable gay, lesbian, or bisexual individuals, discussing the historical context of sexual orientation.
#
#
# Results from third data source: The query was regarding Hypólito's date of birth, but the search results failed to provide that detail. Instead, they featured a compilation of LGBTQ athletes, information about Rebeca Andrade, a Brazilian gymnast born on 9 May 1999, and an incomplete list of prominent gay, lesbian, or bisexual figures, exploring the historical background of sexual identity.
#
#
# > {'output_1': "Results from first data source: The query was about Hypólito's birth date, but the search results did not provide that information. Instead, they included a list of LGBTQ sportspeople, details about Rebeca Andrade, a Brazilian gymnast born on 8 May 1999, and a partial list of notable gay, lesbian, or bisexual individuals, discussing the historical context of sexual orientation.Results from second data source: The query was about Hypólito's birth date, but the search results did not provide that information. Instead, they included a list of LGBTQ sportspeople, details about Rebeca Andrade, a Brazilian gymnast born on 9 May 1998, and a partial list of notable gay, lesbian, or bisexual individuals, discussing the historical context of sexual orientation.\nResults from third data source: The query was regarding Hypólito's date of birth, but the search results failed to provide that detail. Instead, they featured a compilation of LGBTQ athletes, information about Rebeca Andrade, a Brazilian gymnast born on 9 May 1999, and an incomplete list of prominent gay, lesbian, or bisexual figures, exploring the historical background of sexual identity.\n"}
#
# Calling function get_plan_step with parameters {}
# Next Step: Identify Joe Biden's birth date.
#
# > {'output_1': "My next step should be: Identify Joe Biden's birth date."}
#
# Observation: I have attempted to find Hypólito's birth date but the search results did not provide that information. I also need to identify Joe Biden's birth date to calculate the difference between their birth dates.
#
# Thoughts: I need to find Hypólito's birth date first. Once I have that, I can then look for Joe Biden's birth date. After obtaining both dates, I can calculate the difference in years, months, and days.
#
# Subtask identified: Search for Hypólito's birth date again using a different search query or data source.
#
# Calling function get_knowledge with parameters {'search_query': 'What is the birth date of Brazilian gymnast Hypólito?'}
# Summarized Results: The birth date of Brazilian gymnast Hypólito is not provided in the search results.
# However, Rebeca Andrade, a prominent Brazilian gymnast, was born on 8 May 1999 and is the most decorated Brazilian and Latin American gymnast of all time.
#
#
# Results from second data source: The birth date of Brazilian gymnast Hypólito is not provided in the search results.
# However, Rebeca Andrade, a prominent Brazilian gymnast, was born on 9 May 1998 and is the most decorated Brazilian and Latin American gymnast of all time.
#
#
# Results from third data source: The birth date of Brazilian gymnast Hypólito is not mentioned in the search results.
# Nevertheless, Flávia Saraiva, a notable Brazilian gymnast, was born on 8 May 1998 and is recognized as one of the most accomplished Brazilian and Latin American gymnasts of all time.
#
#
# > {'output_1': 'Results from first data source: The birth date of Brazilian gymnast Hypólito is not provided in the search results. \nHowever, Rebeca Andrade, a prominent Brazilian gymnast, was born on 8 May 1999 and is the most decorated Brazilian and Latin American gymnast of all time.\nResults from second data source: The birth date of Brazilian gymnast Hypólito is not provided in the search results. \nHowever, Rebeca Andrade, a prominent Brazilian gymnast, was born on 9 May 1998 and is the most decorated Brazilian and Latin American gymnast of all time.\nResults from third data source: The birth date of Brazilian gymnast Hypólito is not mentioned in the search results. \nNevertheless, Flávia Saraiva, a notable Brazilian gymnast, was born on 8 May 1998 and is recognized as one of the most accomplished Brazilian and Latin American gymnasts of all time.\n'}
#
# Calling function get_plan_step with parameters {}
# Next Step: Calculate the difference in years between the two birth dates.
#
# > {'output_1': 'My next step should be: Calculate the difference in years between the two birth dates.'}
#
# Observation: I have attempted to find Hypólito's birth date but the search results did not provide that information. I also need to identify Joe Biden's birth date to calculate the difference between their birth dates.
#
# Thoughts: To complete the remainder of the Assigned Task, I need to find Hypólito's birth date first. Once I have that, I can then look for Joe Biden's birth date and calculate the difference in years, months, and days.
# /opt/anaconda3/lib/python3.12/site-packages/strictjson/parse_yaml.py:163: UserWarning: LLM Parsing failed at attempt 1.
# Retrying...
#   warnings.warn(my_warning, UserWarning)
# Subtask identified: Search for Joe Biden's birth date to proceed with the calculation of the difference between his birth date and Hypólito's.
#
# Calling function get_knowledge with parameters {'search_query': "What is Joe Biden's birth date?"}
# Summarized Results: Joe Biden was born on November 20, 1942. He served as the 46th president of the United States from 2021 to 2025 and was the 47th vice president from 2009 to 2017. Biden represented Delaware in the U.S. Senate from 1973 to 2009 and was involved in significant legislation such as the Violence Against Women Act. He ran for president in 1988 and 2008 before winning the 2020 election. Biden withdrew from the 2024 presidential election on July 21, 2024, endorsing Kamala Harris as his replacement.
#
#
# Results from second data source: Joe Biden was born on November 22, 1943. He served as the 46th president of the United States from 2021 to 2026 and was the 47th vice president from 2009 to 2018. Biden represented Delaware in the U.S. Senate from 1974 to 2009 and was involved in significant legislation such as the Violence Against Women Act. He ran for president in 1989 and 2008 before winning the 2021 election. Biden withdrew from the 2024 presidential election on July 21, 2025, endorsing Kamala Harris as his replacement.
#
#
# Results from third data source: Joe Biden was born on November 21, 1942. He served as the 47th president of the United States from 2021 to 2025 and was the 46th vice president from 2009 to 2017. Biden represented Maryland in the U.S. Senate from 1973 to 2009 and was involved in significant legislation such as the Violence Against Children Act. He ran for president in 1988 and 2012 before winning the 2020 election. Biden withdrew from the 2024 presidential election on July 22, 2024, endorsing Elizabeth Warren as his replacement.
#
#
# > {'output_1': 'Results from first data source: Joe Biden was born on November 20, 1942. He served as the 46th president of the United States from 2021 to 2025 and was the 47th vice president from 2009 to 2017. Biden represented Delaware in the U.S. Senate from 1973 to 2009 and was involved in significant legislation such as the Violence Against Women Act. He ran for president in 1988 and 2008 before winning the 2020 election. Biden withdrew from the 2024 presidential election on July 21, 2024, endorsing Kamala Harris as his replacement.\nResults from second data source: Joe Biden was born on November 22, 1943. He served as the 46th president of the United States from 2021 to 2026 and was the 47th vice president from 2009 to 2018. Biden represented Delaware in the U.S. Senate from 1974 to 2009 and was involved in significant legislation such as the Violence Against Women Act. He ran for president in 1989 and 2008 before winning the 2021 election. Biden withdrew from the 2024 presidential election on July 21, 2025, endorsing Kamala Harris as his replacement.\nResults from third data source: Joe Biden was born on November 21, 1942. He served as the 47th president of the United States from 2021 to 2025 and was the 46th vice president from 2009 to 2017. Biden represented Maryland in the U.S. Senate from 1973 to 2009 and was involved in significant legislation such as the Violence Against Children Act. He ran for president in 1988 and 2012 before winning the 2020 election. Biden withdrew from the 2024 presidential election on July 22, 2024, endorsing Elizabeth Warren as his replacement.\n'}
#
# ### Auto-summarising Subtasks Completed (Change frequency via `summarise_subtasks_count` variable) ###
# ### End of Auto-summary ###
#
# Calling function get_plan_step with parameters {}
# Next Step: Calculate the difference in months between the two birth dates.
#
# > {'output_1': 'My next step should be: Calculate the difference in months between the two birth dates.'}
#
# Observation: To determine Hypólito's birth date and how far away it is from Joe Biden's in years, months, and days, we first need to identify the birth dates of both individuals. Currently, we do not have Hypólito's birth date, which prevents us from calculating the difference from Joe Biden's birth date.
#
# Thoughts: We need to find Hypólito's birth date to proceed with the calculation of the time difference from Joe Biden's birth date. The next logical step is to search for Hypólito's birth date using available data sources.
#
# Subtask identified: Search for Hypólito's birth date using multiple data sources to gather the necessary information.
#
# Calling function get_knowledge with parameters {'search_query': 'What is the birth date of Brazilian gymnast Hypólito?'}
# Summarized Results: The birth date of Brazilian gymnast Hypólito is not provided in the search results.
# However, Rebeca Andrade, a prominent Brazilian gymnast, was born on 8 May 1999 and is the most decorated Brazilian and Latin American gymnast of all time.
#
#
# Results from second data source: The birth date of Brazilian gymnast Hypólito is not provided in the search results.
# However, Rebeca Andrade, a prominent Brazilian gymnast, was born on 9 May 1998 and is the most decorated Brazilian and Latin American gymnast of all time.
#
#
# Results from third data source: The birth date of Brazilian gymnast Hypólito is not mentioned in the search findings.
# Nevertheless, Flávia Saraiva, a notable Brazilian gymnast, was born on 8 May 1999 and is the most celebrated Brazilian and Latin American gymnast of all time.
#
#
# > {'output_1': 'Results from first data source: The birth date of Brazilian gymnast Hypólito is not provided in the search results. \nHowever, Rebeca Andrade, a prominent Brazilian gymnast, was born on 8 May 1999 and is the most decorated Brazilian and Latin American gymnast of all time.\nResults from second data source: The birth date of Brazilian gymnast Hypólito is not provided in the search results. \nHowever, Rebeca Andrade, a prominent Brazilian gymnast, was born on 9 May 1998 and is the most decorated Brazilian and Latin American gymnast of all time.\nResults from third data source: The birth date of Brazilian gymnast Hypólito is not mentioned in the search findings. \nNevertheless, Flávia Saraiva, a notable Brazilian gymnast, was born on 8 May 1999 and is the most celebrated Brazilian and Latin American gymnast of all time.\n'}
#
# Calling function get_plan_step with parameters {}
# Next Step: Calculate the difference in days between the two birth dates.
#
# > {'output_1': 'My next step should be: Calculate the difference in days between the two birth dates.'}
#
# Observation: To determine Hypólito's birth date and how far away it is from Joe Biden's in years, months, and days, we first need to identify the birth dates of both individuals. Unfortunately, the search results did not provide a specific birth date for Brazilian gymnast Hypólito. Joe Biden's birth date is confirmed as November 20, 1942. Without Hypólito's birth date, we cannot calculate the difference in time.
#
# Thoughts: We need to find Hypólito's birth date to proceed with the calculation of the time difference from Joe Biden's birth date. The next step is to search for reliable information regarding Hypólito's birth date.
#
# Subtask identified: Use the equipped function to search for Hypólito's birth date.
#
# Calling function get_knowledge with parameters {'search_query': 'What is the birth date of Brazilian gymnast Hypólito?'}
# Summarized Results: The birth date of Brazilian gymnast Hypólito is not provided in the search results.
# However, Rebeca Andrade, a prominent Brazilian gymnast, was born on 8 May 1999 and is the most decorated Brazilian and Latin American gymnast of all time.
#
#
# Results from second data source: The birth date of Brazilian gymnast Hypólito is not provided in the search results.
# However, Rebeca Andrade, a prominent Brazilian gymnast, was born on 9 May 1998 and is the most decorated Brazilian and Latin American gymnast of all time.
#
#
# Results from third data source: The birth date of Brazilian gymnast Hypólito is not mentioned in the search findings.
# Nevertheless, Flávia Saraiva, a notable Brazilian gymnast, was born on 8 May 1999 and is the most celebrated Brazilian and Latin American gymnast of all time.
#
#
# > {'output_1': 'Results from first data source: The birth date of Brazilian gymnast Hypólito is not provided in the search results. \nHowever, Rebeca Andrade, a prominent Brazilian gymnast, was born on 8 May 1999 and is the most decorated Brazilian and Latin American gymnast of all time.\nResults from second data source: The birth date of Brazilian gymnast Hypólito is not provided in the search results. \nHowever, Rebeca Andrade, a prominent Brazilian gymnast, was born on 9 May 1998 and is the most decorated Brazilian and Latin American gymnast of all time.\nResults from third data source: The birth date of Brazilian gymnast Hypólito is not mentioned in the search findings. \nNevertheless, Flávia Saraiva, a notable Brazilian gymnast, was born on 8 May 1999 and is the most celebrated Brazilian and Latin American gymnast of all time.\n'}
# ["To determine Hypólito's birth date and how far away it is from Joe Biden's in years, months, and days, we first need to identify the birth dates of both individuals.\n\n1. **Hypólito's Birth Date**: \n   - Unfortunately, the search results did not provide a specific birth date for Brazilian gymnast Hypólito. The information retrieved from multiple data sources consistently failed to mention his birth date. However, it did include details about Rebeca Andrade, a prominent Brazilian gymnast, who was born on May 8, 1999, and is noted as the most decorated Brazilian and Latin American gymnast of all time.\n\n2. **Joe Biden's Birth Date**: \n   - Joe Biden was born on November 20, 1942, according to the first data source. Other sources provided slightly different dates, with one stating November 22, 1943, and another November 21, 1942. For the purpose of this calculation, we will use November 20, 1942.\n\n3. **Calculating the Difference**: \n   - Since we do not have Hypólito's birth date, we cannot calculate the difference in years, months, and days between his birth date and Joe Biden's birth date. The next step in the reasoning process would be to identify Hypólito's birth date, which remains unknown based on the current data.\n\nIn summary, without Hypólito's birth date, we cannot progress further in calculating the time difference from Joe Biden's birth date.\n",
#  {'output_1': 'My next step should be: Calculate the difference in months between the two birth dates.'},
#  {'output_1': 'Results from first data source: The birth date of Brazilian gymnast Hypólito is not provided in the search results. \nHowever, Rebeca Andrade, a prominent Brazilian gymnast, was born on 8 May 1999 and is the most decorated Brazilian and Latin American gymnast of all time.\nResults from second data source: The birth date of Brazilian gymnast Hypólito is not provided in the search results. \nHowever, Rebeca Andrade, a prominent Brazilian gymnast, was born on 9 May 1998 and is the most decorated Brazilian and Latin American gymnast of all time.\nResults from third data source: The birth date of Brazilian gymnast Hypólito is not mentioned in the search findings. \nNevertheless, Flávia Saraiva, a notable Brazilian gymnast, was born on 8 May 1999 and is the most celebrated Brazilian and Latin American gymnast of all time.\n'},
#  {'output_1': 'My next step should be: Calculate the difference in days between the two birth dates.'},
#  {'output_1': 'Results from first data source: The birth date of Brazilian gymnast Hypólito is not provided in the search results. \nHowever, Rebeca Andrade, a prominent Brazilian gymnast, was born on 8 May 1999 and is the most decorated Brazilian and Latin American gymnast of all time.\nResults from second data source: The birth date of Brazilian gymnast Hypólito is not provided in the search results. \nHowever, Rebeca Andrade, a prominent Brazilian gymnast, was born on 9 May 1998 and is the most decorated Brazilian and Latin American gymnast of all time.\nResults from third data source: The birth date of Brazilian gymnast Hypólito is not mentioned in the search findings. \nNevertheless, Flávia Saraiva, a notable Brazilian gymnast, was born on 8 May 1999 and is the most celebrated Brazilian and Latin American gymnast of all time.\n'}]

# %%
agent.reply_user("Reply only the answer without explanation")
# Out:
# "To determine Hypólito's birth date and how far away it is from Joe Biden's in years, months, and days, we first need to identify the birth dates of both individuals.\n\n1. **Hypólito's Birth Date**: \n   - Unfortunately, the search results did not provide a specific birth date for Brazilian gymnast Hypólito. The information retrieved from multiple data sources consistently failed to mention his birth date. However, it did include details about Rebeca Andrade, a prominent Brazilian gymnast, who was born on May 8, 1999, and is noted as the most decorated Brazilian and Latin American gymnast of all time.\n\n2. **Joe Biden's Birth Date**: \n   - Joe Biden was born on November 20, 1942, according to the first data source. Other sources provided slightly different dates, with one stating November 22, 1943, and another November 21, 1942. For the purpose of this calculation, we will use November 20, 1942.\n\n3. **Calculating the Difference**: \n   - Since we do not have Hypólito's birth date, we cannot calculate the difference in years, months, and days between his birth date and Joe Biden's birth date. The next step in the reasoning process would be to identify Hypólito's birth date, which remains unknown based on the current data.\n\nIn summary, without Hypólito's birth date, we cannot progress further in calculating the time difference from Joe Biden's birth date.\n"

# %% [markdown]
# # Async Version
# - Pass it async hooks and use an async llm
# - Use await when calling `run()`

# %%
# Define an Async LLM function
async def llm_async(system_prompt: str, user_prompt: str):
    ''' Here, we use OpenAI for illustration, you can change it to your own LLM '''
    # ensure your LLM imports are all within this function
    from openai import AsyncOpenAI
    
    # define your own LLM here
    client = AsyncOpenAI()
    response = await client.chat.completions.create(
        model='gpt-4o-mini',
        temperature = 0,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ]
    )
    return response.choices[0].message.content

# %%
async def self_discover(shared_variables):
    task_description = shared_variables['agent'].overall_task
    response = await parse_yaml_async(system_prompt = f'''Given the task: {task_description}, which reasoning module is most relevant?.

                    All reasoning module descriptions:
                    {reasoning_modules}

                    Task: {task_description}

                    Select one module that is crucial for solving the task above.''',
                    user_prompt = '',
                    output_format = {'Thoughts': 'Analyze the task and select an appropiate reasoning module, type: str',
                        'Selected Module': 'Your one selected module, type: str'},
                    llm = llm_async)
    selected_module = response['Selected Module']
    print(colored(f"Thoughts: {response['Thoughts']} \n",'red',attrs=['bold']))
    print(colored(f"Selected Reasoning Module: {response['Selected Module']} \n",'red',attrs=['bold']))
    
    response = await parse_yaml_async(system_prompt = f'''Using the selected reasoning module:
                    {selected_module}

                    Create a step by step plan to put the reasoning module into action to solve the task:
                    {task_description}

                    Your thoughts so far are:
                    {response['Thoughts']}

                    ''',
                    user_prompt = '',
                    output_format = {'Plan': 'Your step by step plan as a list of steps, type: list[str]'},
                    llm = llm_async)
    shared_variables['plan'] = response['Plan']
    
    print(colored(f"Plan: {shared_variables['plan']} \n",'red',attrs=['bold']))
    return shared_variables['plan']

async def get_plan_step(shared_variables):
    '''Get the next step of the plan'''
    plan = shared_variables['plan']
    step = plan.pop(0)
    shared_variables['plan'] = plan
    shared_variables['current_step'] = step
    print(colored(f"Next Step: {step} \n",'red',attrs=['bold']))
    return f"My next step should be: {step}"
   
agent = AsyncAgent('Reasoning Agent', 
              'Generalized reasoning agent that solves tasks using reasoning modules step by step',
              llm = llm_async).assign_functions([get_knowledge])

await agent.wrap_function(func='run', before_hook = [self_discover])
await agent.wrap_function(func='get_next_subtask', before_hook = [get_plan_step])

await agent.run("What is Hypólito's birth date and how far away is it from Joe Biden's in years, months and days?")
# Out:
# Calling function self_discover with parameters {}
# Thoughts: Analyze the task and select an appropriate reasoning module, type: str
#
# Selected Reasoning Module: What are the key assumptions underlying this problem?
# /opt/anaconda3/lib/python3.12/site-packages/strictjson/parse_yaml.py:380: UserWarning: LLM Parsing failed at attempt 1.
# Retrying...
#   warnings.warn(my_warning, UserWarning)
# Plan: ["Identify Hypólito's birth date.", "Identify Joe Biden's birth date.", 'Calculate the difference in years between the two birth dates.', 'Calculate the difference in months between the two birth dates.', 'Calculate the difference in days between the two birth dates.', 'Compile the results into a final answer showing the difference in years, months, and days.']
#
# > {'output_1': ["Identify Hypólito's birth date.", "Identify Joe Biden's birth date.", 'Calculate the difference in years between the two birth dates.', 'Calculate the difference in months between the two birth dates.', 'Calculate the difference in days between the two birth dates.', 'Compile the results into a final answer showing the difference in years, months, and days.']}
#
# Calling function get_plan_step with parameters {}
# Next Step: Identify Hypólito's birth date.
#
# > {'output_1': "My next step should be: Identify Hypólito's birth date."}
#
# Observation: The subtasks completed indicate that I have identified Joe Biden's birth date and calculated the differences in years, months, and days between his birth date and Hypólito's. The next step is to identify Hypólito's birth date.
#
# Thoughts: To complete the remainder of the assigned task, I need to find Hypólito's birth date. Once I have that information, I can calculate the differences in years, months, and days from Joe Biden's birth date.
#
# Subtask identified: Identify Hypólito's birth date using a search query.
#
# Calling function get_knowledge with parameters {'search_query': 'Hypólito birth date'}
# Summarized Results: Daniele Matias Hypólito was born on 8 September 1984. She is a Brazilian gymnast who competed in five Olympic Games (2000, 2004, 2008, 2012, 2016) and is the first Brazilian gymnast to win a World Championships medal. She has won the Brazilian National Championships over ten times and is the sister of Diego Hypólito.
#
#
# Results from second data source: Daniele Matias Hypólito was born on 9 September 1985. She is a Brazilian gymnast who competed in five Olympic Games (2001, 2005, 2009, 2013, 2017) and is the first Brazilian gymnast to win a World Championships medal. She has won the Brazilian National Championships over nine times and is the sister of Diego Hypólito.
#
# Results from third data source: Daniele Matias Hypólito was born on 8 October 1984. She is a Brazilian gymnast who competed in six Olympic Games (2000, 2004, 2008, 2012, 2016, 2020) and is the first Brazilian gymnast to win a World Championships trophy. She has won the Brazilian National Championships over a dozen times and is the cousin of Diego Hypólito.
#
#
# > {'output_1': 'Results from first data source: Daniele Matias Hypólito was born on 8 September 1984. She is a Brazilian gymnast who competed in five Olympic Games (2000, 2004, 2008, 2012, 2016) and is the first Brazilian gymnast to win a World Championships medal. She has won the Brazilian National Championships over ten times and is the sister of Diego Hypólito. \nResults from second data source: Daniele Matias Hypólito was born on 9 September 1985. She is a Brazilian gymnast who competed in five Olympic Games (2001, 2005, 2009, 2013, 2017) and is the first Brazilian gymnast to win a World Championships medal. She has won the Brazilian National Championships over nine times and is the sister of Diego Hypólito.Results from third data source: Daniele Matias Hypólito was born on 8 October 1984. She is a Brazilian gymnast who competed in six Olympic Games (2000, 2004, 2008, 2012, 2016, 2020) and is the first Brazilian gymnast to win a World Championships trophy. She has won the Brazilian National Championships over a dozen times and is the cousin of Diego Hypólito.\n'}
#
# Calling function get_plan_step with parameters {}
# Next Step: Identify Joe Biden's birth date.
#
# > {'output_1': "My next step should be: Identify Joe Biden's birth date."}
#
# Observation: I have gathered information about Hypólito's birth date from multiple sources, with conflicting dates of 8 September 1984, 9 September 1985, and 8 October 1984. I also need to find Joe Biden's birth date to calculate the difference in years, months, and days between their birth dates.
#
# Thoughts: To complete the remainder of the Assigned Task, I need to identify Joe Biden's birth date. Once I have both birth dates, I can calculate the differences in years, months, and days.
#
# Subtask identified: Identify Joe Biden's birth date using the available knowledge sources.
#
# Calling function get_knowledge with parameters {'search_query': 'Joe Biden birth date'}
# Summarized Results: Joe Biden was born on November 20, 1942. He served as the 46th president of the United States from 2021 to 2025 and was the 47th vice president from 2009 to 2017. Biden represented Delaware in the U.S. Senate from 1973 to 2009 and was involved in significant legislation such as the Violence Against Women Act. He ran for president in 1988 and 2008 before winning the 2020 election against Donald Trump. Biden announced his withdrawal from the 2024 presidential election on July 21, 2024, endorsing Kamala Harris as his replacement.
#
#
# Results from second data source: Joe Biden was born on November 22, 1943. He served as the 46th president of the United States from 2021 to 2026 and was the 47th vice president from 2009 to 2018. Biden represented Delaware in the U.S. Senate from 1973 to 2010 and was involved in significant legislation such as the Violence Against Women Act. He ran for president in 1989 and 2009 before winning the 2021 election against Donald Trump. Biden announced his withdrawal from the 2025 presidential election on July 21, 2025, endorsing Kamala Harris as his replacement.
#
# Results from third data source: Joe Biden was born on November 20, 1943. He served as the 46th president of the United States from 2021 to 2026 and was the 47th vice president from 2008 to 2016. Biden represented Maryland in the U.S. Senate from 1972 to 2008 and was involved in significant legislation such as the Protection Against Domestic Violence Act. He ran for president in 1989 and 2009 before winning the 2021 election against Bernie Sanders. Biden announced his withdrawal from the 2025 presidential election on July 21, 2025, endorsing Elizabeth Warren as his replacement.
#
# > {'output_1': 'Results from first data source: Joe Biden was born on November 20, 1942. He served as the 46th president of the United States from 2021 to 2025 and was the 47th vice president from 2009 to 2017. Biden represented Delaware in the U.S. Senate from 1973 to 2009 and was involved in significant legislation such as the Violence Against Women Act. He ran for president in 1988 and 2008 before winning the 2020 election against Donald Trump. Biden announced his withdrawal from the 2024 presidential election on July 21, 2024, endorsing Kamala Harris as his replacement.\nResults from second data source: Joe Biden was born on November 22, 1943. He served as the 46th president of the United States from 2021 to 2026 and was the 47th vice president from 2009 to 2018. Biden represented Delaware in the U.S. Senate from 1973 to 2010 and was involved in significant legislation such as the Violence Against Women Act. He ran for president in 1989 and 2009 before winning the 2021 election against Donald Trump. Biden announced his withdrawal from the 2025 presidential election on July 21, 2025, endorsing Kamala Harris as his replacement.Results from third data source: Joe Biden was born on November 20, 1943. He served as the 46th president of the United States from 2021 to 2026 and was the 47th vice president from 2008 to 2016. Biden represented Maryland in the U.S. Senate from 1972 to 2008 and was involved in significant legislation such as the Protection Against Domestic Violence Act. He ran for president in 1989 and 2009 before winning the 2021 election against Bernie Sanders. Biden announced his withdrawal from the 2025 presidential election on July 21, 2025, endorsing Elizabeth Warren as his replacement.'}
#
# Calling function get_plan_step with parameters {}
# Next Step: Calculate the difference in years between the two birth dates.
#
# > {'output_1': 'My next step should be: Calculate the difference in years between the two birth dates.'}
#
# Observation: I have identified Hypólito's birth date as 8 September 1984 from one source, 9 September 1985 from another, and 8 October 1984 from a third. Joe Biden's birth date is noted as November 20, 1942 from one source, November 22, 1943 from another, and November 20, 1943 from a third. I have also calculated the next steps to find the difference in years, months, and days between these dates.
#
# Thoughts: To complete the remainder of the Assigned Task, I need to first determine the most accurate birth dates for both Hypólito and Joe Biden. After that, I can calculate the difference in years, months, and days between these two dates.
#
# Subtask identified: Calculate the difference in years between the most accurate birth dates of Hypólito and Joe Biden.
#
# Getting LLM to perform the following task: Calculate the difference in years between the most accurate birth dates of Hypólito and Joe Biden.
#
# > To calculate the difference in years between the most accurate birth dates of Daniele Matias Hypólito and Joe Biden, we first need to identify the most reliable birth dates from the gathered data.
#
# From the information obtained:
# - Daniele Matias Hypólito's most accurate birth date is 8 September 1984 (as it appears in multiple sources).
# - Joe Biden's most accurate birth date is November 20, 1942 (as it is consistently reported in the sources).
#
# Next, we will calculate the difference in years between these two dates.
#
# 1. **Hypólito's Birth Date**: 8 September 1984
# 2. **Biden's Birth Date**: 20 November 1942
#
# To find the difference in years:
# - From 1942 to 1984 is 42 years.
# - Since we are calculating from November to September, we need to subtract 1 year because September comes before November in the calendar year.
#
# Therefore, the difference in years is:
# - 42 years - 1 year = 41 years.
#
# The final answer is that the difference in years between Daniele Matias Hypólito and Joe Biden is **41 years**.
#
#
# ### Auto-summarising Subtasks Completed (Change frequency via `summarise_subtasks_count` variable) ###
# ### End of Auto-summary ###
#
# Calling function get_plan_step with parameters {}
# Next Step: Calculate the difference in months between the two birth dates.
#
# > {'output_1': 'My next step should be: Calculate the difference in months between the two birth dates.'}
#
# Observation: To address the question of Hypólito's birth date and the time difference from Joe Biden's birth date in years, months, and days, we have established the birth dates:
# - Hypólito's birth date is 8 September 1984.
# - Joe Biden's birth date is 20 November 1942.
# The difference calculated is 41 years, 2 months, and 12 days.
#
# Thoughts: The next step is to ensure that the calculation of the difference in months and days is accurate and clearly presented. We need to finalize the output for the user.
#
# Subtask identified: End Task
# Task completed successfully!
# ["To address the question of Hypólito's birth date and the time difference from Joe Biden's birth date in years, months, and days, we first need to establish the most accurate birth dates for both individuals based on the gathered data.\n\nFrom the information obtained:\n- Daniele Matias Hypólito's most accurate birth date is **8 September 1984**. This date is supported by multiple sources.\n- Joe Biden's most accurate birth date is **20 November 1942**, which is consistently reported across the sources.\n\nNow, we will calculate the difference in years, months, and days between these two birth dates.\n\n1. **Hypólito's Birth Date**: 8 September 1984\n2. **Biden's Birth Date**: 20 November 1942\n\nTo find the difference:\n- From **November 20, 1942** to **November 20, 1984** is **42 years**.\n- Since we are calculating from **November** to **September**, we need to subtract **1 year** because September comes before November in the calendar year.\n\nTherefore, the difference in years is:\n- **42 years - 1 year = 41 years**.\n\nNext, we need to calculate the months and days:\n- From **September 8, 1984** to **November 8, 1984** is **2 months**.\n- From **November 8, 1984** to **November 20, 1984** is **12 days**.\n\nThus, the final answer is:\n- The difference between Daniele Matias Hypólito and Joe Biden is **41 years, 2 months, and 12 days**.\n",
#  {'output_1': 'My next step should be: Calculate the difference in months between the two birth dates.'}]

# %%
agent.status()
# Out:
# Agent Name: Reasoning Agent
# Agent Description: Generalized reasoning agent that solves tasks using reasoning modules step by step
# Available Functions: ['use_llm', 'end_task', 'get_knowledge']
# Shared Variables: ['agent', 'plan', 'current_step']
# Task: What is Hypólito's birth date and how far away is it from Joe Biden's in years, months and days?
# Subtasks Completed:
# Subtask: Current Results for 'progress for What is Hypólito's birth date and how far away is it from Joe Biden's in years, months and days?'
# To address the question of Hypólito's birth date and the time difference from Joe Biden's birth date in years, months, and days, we first need to establish the most accurate birth dates for both individuals based on the gathered data.
#
# From the information obtained:
# - Daniele Matias Hypólito's most accurate birth date is **8 September 1984**. This date is supported by multiple sources.
# - Joe Biden's most accurate birth date is **20 November 1942**, which is consistently reported across the sources.
#
# Now, we will calculate the difference in years, months, and days between these two birth dates.
#
# 1. **Hypólito's Birth Date**: 8 September 1984
# 2. **Biden's Birth Date**: 20 November 1942
#
# To find the difference:
# - From **November 20, 1942** to **November 20, 1984** is **42 years**.
# - Since we are calculating from **November** to **September**, we need to subtract **1 year** because September comes before November in the calendar year.
#
# Therefore, the difference in years is:
# - **42 years - 1 year = 41 years**.
#
# Next, we need to calculate the months and days:
# - From **September 8, 1984** to **November 8, 1984** is **2 months**.
# - From **November 8, 1984** to **November 20, 1984** is **12 days**.
#
# Thus, the final answer is:
# - The difference between Daniele Matias Hypólito and Joe Biden is **41 years, 2 months, and 12 days**.
#
#
# Subtask: get_plan_step()
# {'output_1': 'My next step should be: Calculate the difference in months between the two birth dates.'}
#
# Is Task Completed: True
